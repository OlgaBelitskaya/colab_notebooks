# %% [markdown]
# ## Modules & Functions

# %%
# !pip install --upgrade neural_structured_learning --user
# Out:
# Requirement already up-to-date: neural_structured_learning in /root/.local/lib/python3.6/site-packages (1.1.0)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (1.12.0)
# Requirement already satisfied, skipping upgrade: absl-py in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (0.9.0)
# Requirement already satisfied, skipping upgrade: attrs in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (19.3.0)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.6/dist-packages (from neural_structured_learning) (1.4.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scipy->neural_structured_learning) (1.18.4)

# %%
path='/root/.local/lib/python3.6/site-packages'
import sys; sys.path.append(path)
import numpy as np,pylab as pl,pandas as pd
import sys,h5py,urllib,zipfile
import tensorflow as tf
import neural_structured_learning as nsl
from sklearn import datasets
from sklearn.model_selection import train_test_split
from keras.datasets import mnist
from keras.utils import to_categorical

# %%
def display_10img(X,y,s):
    fig,ax=pl.subplots(figsize=(10,3),nrows=2,ncols=5,
                       sharex=True,sharey=True)
    ax=ax.flatten()
    for i in range(10):
        ax[i].imshow(X[i].reshape(s,s),cmap=pl.cm.Greens)
        ax[i].set_title(y[i])
    ax[0].set_xticks([]); ax[0].set_yticks([])
    pl.tight_layout()
def prepro(x_train,y_train,x_test,y_test,n_class):
    n=int(len(x_test)/2)    
    x_valid,y_valid=x_test[:n],y_test[:n]
    x_test,y_test=x_test[n:],y_test[n:]
    cy_train=to_categorical(y_train,n_class) 
    cy_valid=to_categorical(y_valid,n_class)
    cy_test=to_categorical(y_test,n_class)
    df=pd.DataFrame([[x_train.shape,x_valid.shape,x_test.shape],
                     [y_train.shape,y_valid.shape,y_test.shape],
                     [cy_train.shape,cy_valid.shape,cy_test.shape]],
                    columns=['train','valid','test'],
                    index=['images','labels','encoded labels'])
    display(df)
    return [[x_train,x_valid,x_test],
            [y_train,y_valid,y_test],
            [cy_train,cy_valid,cy_test]]

# %% [markdown]
# ## Data
# ### #1

# %%
digits=datasets.load_digits(n_class=10)
X1,y1=digits.data,digits.target
X_train1,X_test1,y_train1,y_test1=\
train_test_split(X1,y1,test_size=.2,random_state=1)
display_10img(X_train1,y_train1,8)

# %% [markdown]
# ### #2

# %%
(X_train2,y_train2),(X_test2,y_test2)=mnist.load_data()
X_train2=X_train2.reshape(-1,784).astype('float32')
X_test2=X_test2.reshape(-1,784).astype('float32')
y_train2=y_train2.astype('int32')
y_test2=y_test2.astype('int32')
[[X_train2,X_valid2,X_test2],
 [y_train2,y_valid2,y_test2],
 [cy_train2,cy_valid2,cy_test2]]=\
prepro(X_train2,y_train2,X_test2,y_test2,10)
display_10img(X_train2,y_train2,28)
# Out:
#                        train        valid         test
# images          (60000, 784)  (5000, 784)  (5000, 784)
# labels              (60000,)      (5000,)      (5000,)
# encoded labels   (60000, 10)   (5000, 10)   (5000, 10)

# %% [markdown]
# ### #3

# %%
fpath='https://olgabelitskaya.github.io/'
zf='LetterColorImages_123.h5.zip'
input_file=urllib.request.urlopen(fpath+zf)
output_file=open(zf,'wb'); 
output_file.write(input_file.read())
output_file.close(); input_file.close()
zipf=zipfile.ZipFile(zf,'r')
zipf.extractall(''); zipf.close()
f=h5py.File(zf[:-4],'r')
keys=list(f.keys()); rn=10**3
letters=u'абвгдеёжзийклмнопрстуфхцчшщъыьэюя'
X3=np.array(f[keys[1]])/255
X3=1-np.dot(X3[...,:3],[.299,.587,.114])
y3=np.array(f[keys[2]])-1
X_train3,X_test3,y_train3,y_test3=\
train_test_split(X3,y3,test_size=.2,random_state=1)
X_train3=X_train3.reshape(-1,32*32).astype('float32')
X_test3=X_test3.reshape(-1,32*32).astype('float32')
y_train3=y_train3.astype('int32')
y_test3=y_test3.astype('int32')
[[X_train3,X_valid3,X_test3],
 [y_train3,y_valid3,y_test3],
 [cy_train3,cy_valid3,cy_test3]]=\
prepro(X_train3,y_train3,X_test3,y_test3,33)
display_10img(X_train3,y_train3,32)
# Out:
#                         train         valid          test
# images          (11352, 1024)  (1419, 1024)  (1419, 1024)
# labels               (11352,)       (1419,)       (1419,)
# encoded labels    (11352, 33)    (1419, 33)    (1419, 33)

# %% [markdown]
# ## Neural Networks
# ### #1

# %%
def trainNN(X,y,D,K,h,a,r,step_size,epochs):
    W1=a*np.random.randn(D,h)
    b1=np.zeros((1,h))
    W2=a*np.random.randn(h,K)
    b2=np.zeros((1,K))
    # gradient descent loop
    num_examples=X.shape[0]
    for i in range(epochs): 
        # evaluate class scores
        hidden_layer=np.maximum(0,np.dot(X,W1)+b1) # ReLU activation
        scores=np.dot(hidden_layer,W2)+b2  
        # compute the class probabilities
        exp_scores=np.exp(scores)
        probs=exp_scores/np.sum(exp_scores,axis=1,keepdims=True)   
        # compute the loss: average cross-entropy loss and regularization
        corect_logprobs=-np.log(probs[range(num_examples),y])
        data_loss=np.sum(corect_logprobs)/num_examples
        reg_loss=.5*r*np.sum(W1**2)+.5*r*np.sum(W2**2)
        loss=data_loss+reg_loss
        if (i+1)%500==0:
            print("iteration %d: loss %f"%(i+1,loss))  
        # compute the gradient on scores
        dscores=probs
        dscores[range(num_examples),y]-=1
        dscores/=num_examples  
        # backpropate the gradient to the parameters
        # first backprop into parameters W2 and b2
        dW2=np.dot(hidden_layer.T,dscores)
        db2=np.sum(dscores,axis=0,keepdims=True)
        # next backprop into hidden layer
        dhidden=np.dot(dscores,W2.T)
        # backprop the ReLU non-linearity
        dhidden[hidden_layer<=0]=0
        # finally into W,b
        dW1=np.dot(X.T,dhidden)
        db1=np.sum(dhidden,axis=0,keepdims=True)  
        # add regularization gradient contribution
        dW2+=r*W2; dW1+=r*W1  
        # perform a parameter update
        W1+=-step_size1*dW1; b1+=-step_size1*db1
        W2+=-step_size1*dW2; b2+=-step_size1*db2
    return [W1,b1,W2,b2]
def predict(X,W1,b1,W2,b2):
    hidden_layer=np.maximum(0,np.dot(X,W1)+b1)
    scores=np.dot(hidden_layer,W2)+b2
    return np.argmax(scores,axis=1)
def accuracy(y,py): return np.mean(py==y)*100

# %%
D1=64 # dimensionality
K1=10 # number of classes
h1=320 # size of hidden layer
# hyperparameters
a1=1e-3; step_size1=1e-2; epochs1=2500
r1=1e-4 # regularization strength
[W11,b11,W12,b12]=\
trainNN(X_train1,y_train1,D1,K1,h1,
        a1,r1,step_size1,epochs1)
# Out:
# iteration 500: loss 0.169008
# iteration 1000: loss 0.087080
# iteration 1500: loss 0.059363
# iteration 2000: loss 0.043697
# iteration 2500: loss 0.033546

# %%
py_train1=predict(X_train1,W11,b11,W12,b12)
acc_train1=accuracy(y_train1,py_train1)
print('Digits. Train accuracy: %.2f'%acc_train1)
py_test1=predict(X_test1,W11,b11,W12,b12)
acc_test1=accuracy(y_test1,py_test1)
print('Digits. Test accuracy: %.2f'%acc_test1)
# Out:
# Digits. Train accuracy: 99.58
# Digits. Test accuracy: 96.94

# %% [markdown]
# ### #2

# %%
lr=.001; epochs=12; hidden1=256; hidden2=256
batch_size=128; display_step=1; 
n_inputs=784; n_classes=10

# %%
def cat_accuracy(predictions,labels):
    return (100.0*np.sum(np.argmax(predictions,1)==\
           np.argmax(labels,1))/predictions.shape[0])
def mlp(x):
    layer1=tf.add(tf.matmul(x,weights['W1']),biases['b1'])
    layer2=tf.add(tf.matmul(layer1,weights['W2']),biases['b2'])
    return tf.matmul(layer2,weights['out'])+biases['out']
graph=tf.Graph()
with graph.as_default():
    X=tf.compat.v1.placeholder("float32",[None,n_inputs])
    y=tf.compat.v1.placeholder("int32",[None,n_classes])
    vX=tf.constant(X_test2)
    weights={'W1':tf.Variable(\
                  tf.compat.v1.random_normal([n_inputs,hidden1])),
             'W2':tf.Variable(\
                  tf.compat.v1.random_normal([hidden1,hidden2])),
             'out':tf.Variable(\
                   tf.compat.v1.random_normal([hidden2,n_classes]))}
    biases={'b1':tf.Variable(\
                 tf.compat.v1.random_normal([hidden1])),
            'b2':tf.Variable(\
                 tf.compat.v1.random_normal([hidden2])),
            'out':tf.Variable(\
                  tf.compat.v1.random_normal([n_classes]))}
    logits=mlp(X); vlogits=mlp(vX)
    loss=tf.reduce_mean(\
    tf.nn.softmax_cross_entropy_with_logits(logits=logits,labels=y))
    optimizer=tf.compat.v1.train.AdamOptimizer(learning_rate=lr)
    train_opt=optimizer.minimize(loss)
    train_predictions=tf.nn.softmax(logits)
    test_predictions=tf.nn.softmax(vlogits)

# %%
with tf.compat.v1.Session(graph=graph) as sess:
    tf.compat.v1.global_variables_initializer().run()
    for epoch in range(epochs):
        avg_loss=0.; avg_acc=0.
        total_batch=int(X_train2.shape[0]/batch_size)
        for i in range(total_batch):
            offset=(i*batch_size)%(X_train2.shape[0]-batch_size)
            batch_X=X_train2[offset:(offset+batch_size)]
            batch_y=cy_train2[offset:(offset+batch_size)]
            _,l,batch_py=sess.run([train_opt,loss,train_predictions],
                                  feed_dict={X:batch_X,y:batch_y})
            avg_loss+=l/total_batch
            avg_acc+=cat_accuracy(batch_py,batch_y)/total_batch
        if epoch%display_step==0:
            print("Epoch: %04d"%(epoch+1),
                  "loss={:.9f}".format(avg_loss),
                  "accuracy={:.3f}".format(avg_acc))
    print("Test accuracy: %.3f%%"%\
    cat_accuracy(test_predictions.eval(),cy_test2))
# Out:
# Epoch: 0001 loss=83787.691715077 accuracy=75.012
# Epoch: 0002 loss=26877.276223990 accuracy=86.286
# Epoch: 0003 loss=19977.073383820 accuracy=87.523
# Epoch: 0004 loss=16360.560519748 accuracy=87.884
# Epoch: 0005 loss=13947.423354190 accuracy=88.285
# Epoch: 0006 loss=12042.080442901 accuracy=88.487
# Epoch: 0007 loss=10739.961659097 accuracy=88.602
# Epoch: 0008 loss=9802.932873848 accuracy=88.752
# Epoch: 0009 loss=8963.363727928 accuracy=88.622
# Epoch: 0010 loss=8308.287046644 accuracy=88.734
# Epoch: 0011 loss=7631.407574254 accuracy=88.805
# Epoch: 0012 loss=7262.654050322 accuracy=88.854
# Test accuracy: 92.080%

# %% [markdown]
# ### #3

# %%
# data 2
batch_size=64; img_size=28; n_class=10; epochs=7

# %%
base_model=tf.keras.Sequential([
    tf.keras.Input((img_size,img_size),name='input'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128,activation=tf.nn.relu),
    tf.keras.layers.BatchNormalization(),    
    tf.keras.layers.Dense(256,activation=tf.nn.relu),
    tf.keras.layers.Dense(n_class,activation=tf.nn.softmax)
])
adv_config=nsl.configs\
.make_adv_reg_config(multiplier=.2,adv_step_size=.05)
adv_model=nsl.keras\
.AdversarialRegularization(base_model,adv_config=adv_config)
adv_model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

# %%
train2=tf.data.Dataset.from_tensor_slices(
    {'input':X_train2,'label':y_train2}).batch(batch_size)
valid2=tf.data.Dataset.from_tensor_slices(
    {'input':X_valid2,'label':y_valid2}).batch(batch_size)
valid_steps=X_valid2.shape[0]//batch_size
adv_model.fit(train2,validation_data=valid2,verbose=2,
              validation_steps=valid_steps,epochs=epochs);
# Out:
# Epoch 1/7
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input Tensor("input_2:0", shape=(None, 28, 28), dtype=float32), but it was called on an input with incompatible shape (None, 784).
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input Tensor("input_2:0", shape=(None, 28, 28), dtype=float32), but it was called on an input with incompatible shape (None, 784).
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input Tensor("input_2:0", shape=(None, 28, 28), dtype=float32), but it was called on an input with incompatible shape (None, 784).
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input Tensor("input_2:0", shape=(None, 28, 28), dtype=float32), but it was called on an input with incompatible shape (None, 784).
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input Tensor("input_2:0", shape=(None, 28, 28), dtype=float32), but it was called on an input with incompatible shape (None, 784).
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input Tensor("input_2:0", shape=(None, 28, 28), dtype=float32), but it was called on an input with incompatible shape (None, 784).
# 938/938 - 6s - loss: 0.2572 - sparse_categorical_crossentropy: 0.2143 - sparse_categorical_accuracy: 0.9347 - adversarial_loss: 0.2145 - val_loss: 0.2115 - val_sparse_categorical_crossentropy: 0.1762 - val_sparse_categorical_accuracy: 0.9435 - val_adversarial_loss: 0.1764
# Epoch 2/7
# 938/938 - 5s - loss: 0.1075 - sparse_categorical_crossentropy: 0.0895 - sparse_categorical_accuracy: 0.9724 - adversarial_loss: 0.0897 - val_loss: 0.2005 - val_sparse_categorical_crossentropy: 0.1670 - val_sparse_categorical_accuracy: 0.9481 - val_adversarial_loss: 0.1672
# Epoch 3/7
# 938/938 - 5s - loss: 0.0692 - sparse_categorical_crossentropy: 0.0577 - sparse_categorical_accuracy: 0.9817 - adversarial_loss: 0.0578 - val_loss: 0.1810 - val_sparse_categorical_crossentropy: 0.1508 - val_sparse_categorical_accuracy: 0.9557 - val_adversarial_loss: 0.1510
# Epoch 4/7
# 938/938 - 6s - loss: 0.0495 - sparse_categorical_crossentropy: 0.0412 - sparse_categorical_accuracy: 0.9869 - adversarial_loss: 0.0413 - val_loss: 0.1738 - val_sparse_categorical_crossentropy: 0.1448 - val_sparse_categorical_accuracy: 0.9587 - val_adversarial_loss: 0.1449
# Epoch 5/7
# 938/938 - 5s - loss: 0.0347 - sparse_categorical_crossentropy: 0.0289 - sparse_categorical_accuracy: 0.9905 - adversarial_loss: 0.0290 - val_loss: 0.1682 - val_sparse_categorical_crossentropy: 0.1401 - val_sparse_categorical_accuracy: 0.9641 - val_adversarial_loss: 0.1403
# Epoch 6/7
# 938/938 - 6s - loss: 0.0288 - sparse_categorical_crossentropy: 0.0240 - sparse_categorical_accuracy: 0.9923 - adversarial_loss: 0.0241 - val_loss: 0.2082 - val_sparse_categorical_crossentropy: 0.1735 - val_sparse_categorical_accuracy: 0.9617 - val_adversarial_loss: 0.1737
# Epoch 7/7
# 938/938 - 6s - loss: 0.0251 - sparse_categorical_crossentropy: 0.0209 - sparse_categorical_accuracy: 0.9930 - adversarial_loss: 0.0210 - val_loss: 0.2713 - val_sparse_categorical_crossentropy: 0.2261 - val_sparse_categorical_accuracy: 0.9609 - val_adversarial_loss: 0.2264

# %%
scores2=adv_model.evaluate({'input':X_test2,'label':y_test2})
print("Test accuracy: %.1f"%(scores2[2]*100.))
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input Tensor("input_2:0", shape=(None, 28, 28), dtype=float32), but it was called on an input with incompatible shape (None, 784).
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input Tensor("input_2:0", shape=(None, 28, 28), dtype=float32), but it was called on an input with incompatible shape (None, 784).
# 157/157 [==============================] - 0s 3ms/step - loss: 0.1115 - sparse_categorical_crossentropy: 0.0929 - sparse_categorical_accuracy: 0.9830 - adversarial_loss: 0.0930
# Test accuracy: 98.3

# %%
# data3
batch_size=128; img_size=32; n_class=33; epochs=100

# %%
base_model=tf.keras.models.Sequential([
        tf.keras.Input((img_size,img_size),name='input'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128,activation='relu'),
        tf.keras.layers.BatchNormalization(),    
        tf.keras.layers.Dense(256,activation='relu'),
        tf.keras.layers.BatchNormalization(),    
        tf.keras.layers.Dense(512,activation='relu'),
        tf.keras.layers.BatchNormalization(),   
        tf.keras.layers.Dense(1024,activation='relu'),
        tf.keras.layers.Dense(33,activation='softmax')
    ])
adv_config=nsl.configs\
.make_adv_reg_config(multiplier=.2,adv_step_size=.05)
adv_model=nsl.keras\
.AdversarialRegularization(base_model,adv_config=adv_config)
adv_model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# %%
train3=tf.data.Dataset.from_tensor_slices(
    {'input':X_train3,'label':cy_train3}).batch(batch_size)
valid3=tf.data.Dataset.from_tensor_slices(
    {'input':X_valid3,'label':cy_valid3}).batch(batch_size)
valid_steps=X_valid3.shape[0]//batch_size
adv_model.fit(train3,validation_data=valid3,verbose=2,
              validation_steps=valid_steps,epochs=epochs)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Model was constructed with shape (None, 32, 32) for input Tensor("input_3:0", shape=(None, 32, 32), dtype=float32), but it was called on an input with incompatible shape (None, 1024).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 32) for input Tensor("input_3:0", shape=(None, 32, 32), dtype=float32), but it was called on an input with incompatible shape (None, 1024).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 32) for input Tensor("input_3:0", shape=(None, 32, 32), dtype=float32), but it was called on an input with incompatible shape (None, 1024).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 32) for input Tensor("input_3:0", shape=(None, 32, 32), dtype=float32), but it was called on an input with incompatible shape (None, 1024).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 32) for input Tensor("input_3:0", shape=(None, 32, 32), dtype=float32), but it was called on an input with incompatible shape (None, 1024).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 32) for input Tensor("input_3:0", shape=(None, 32, 32), dtype=float32), but it was called on an input with incompatible shape (None, 1024).
# 89/89 - 4s - loss: 3.5699 - categorical_crossentropy: 2.8483 - categorical_accuracy: 0.2162 - adversarial_loss: 3.6082 - val_loss: 4.0484 - val_categorical_crossentropy: 3.3539 - val_categorical_accuracy: 0.1108 - val_adversarial_loss: 3.4725
# Epoch 2/100
# 89/89 - 4s - loss: 2.7469 - categorical_crossentropy: 2.1534 - categorical_accuracy: 0.3797 - adversarial_loss: 2.9677 - val_loss: 4.8826 - val_categorical_crossentropy: 3.9688 - val_categorical_accuracy: 0.1151 - val_adversarial_loss: 4.5691
# Epoch 3/100
# 89/89 - 4s - loss: 2.2593 - categorical_crossentropy: 1.7442 - categorical_accuracy: 0.4822 - adversarial_loss: 2.5755 - val_loss: 5.9238 - val_categorical_crossentropy: 4.8238 - val_categorical_accuracy: 0.1229 - val_adversarial_loss: 5.5001
# Epoch 4/100
# 89/89 - 4s - loss: 1.9103 - categorical_crossentropy: 1.4553 - categorical_accuracy: 0.5637 - adversarial_loss: 2.2754 - val_loss: 8.0441 - val_categorical_crossentropy: 6.5410 - val_categorical_accuracy: 0.1101 - val_adversarial_loss: 7.5159
# Epoch 5/100
# 89/89 - 4s - loss: 1.6683 - categorical_crossentropy: 1.2555 - categorical_accuracy: 0.6208 - adversarial_loss: 2.0639 - val_loss: 5.0747 - val_categorical_crossentropy: 4.0921 - val_categorical_accuracy: 0.1875 - val_adversarial_loss: 4.9130
# Epoch 6/100
# 89/89 - 4s - loss: 1.4467 - categorical_crossentropy: 1.0730 - categorical_accuracy: 0.6763 - adversarial_loss: 1.8684 - val_loss: 6.1493 - val_categorical_crossentropy: 4.9791 - val_categorical_accuracy: 0.1406 - val_adversarial_loss: 5.8509
# Epoch 7/100
# 89/89 - 4s - loss: 1.2660 - categorical_crossentropy: 0.9232 - categorical_accuracy: 0.7252 - adversarial_loss: 1.7141 - val_loss: 6.6407 - val_categorical_crossentropy: 5.3989 - val_categorical_accuracy: 0.1413 - val_adversarial_loss: 6.2091
# Epoch 8/100
# 89/89 - 4s - loss: 1.1854 - categorical_crossentropy: 0.8548 - categorical_accuracy: 0.7398 - adversarial_loss: 1.6534 - val_loss: 8.9376 - val_categorical_crossentropy: 7.2309 - val_categorical_accuracy: 0.1399 - val_adversarial_loss: 8.5331
# Epoch 9/100
# 89/89 - 4s - loss: 1.0702 - categorical_crossentropy: 0.7624 - categorical_accuracy: 0.7685 - adversarial_loss: 1.5389 - val_loss: 9.5785 - val_categorical_crossentropy: 7.7524 - val_categorical_accuracy: 0.1307 - val_adversarial_loss: 9.1307
# Epoch 10/100
# 89/89 - 4s - loss: 0.9959 - categorical_crossentropy: 0.7010 - categorical_accuracy: 0.7861 - adversarial_loss: 1.4745 - val_loss: 9.4998 - val_categorical_crossentropy: 7.6763 - val_categorical_accuracy: 0.1186 - val_adversarial_loss: 9.1170
# Epoch 11/100
# 89/89 - 4s - loss: 0.9095 - categorical_crossentropy: 0.6304 - categorical_accuracy: 0.8078 - adversarial_loss: 1.3953 - val_loss: 9.0351 - val_categorical_crossentropy: 7.2946 - val_categorical_accuracy: 0.1484 - val_adversarial_loss: 8.7021
# Epoch 12/100
# 89/89 - 4s - loss: 0.8530 - categorical_crossentropy: 0.5833 - categorical_accuracy: 0.8202 - adversarial_loss: 1.3486 - val_loss: 8.7929 - val_categorical_crossentropy: 7.0842 - val_categorical_accuracy: 0.1420 - val_adversarial_loss: 8.5435
# Epoch 13/100
# 89/89 - 4s - loss: 0.7502 - categorical_crossentropy: 0.5007 - categorical_accuracy: 0.8480 - adversarial_loss: 1.2473 - val_loss: 5.8453 - val_categorical_crossentropy: 4.6449 - val_categorical_accuracy: 0.2379 - val_adversarial_loss: 6.0018
# Epoch 14/100
# 89/89 - 4s - loss: 0.6447 - categorical_crossentropy: 0.4204 - categorical_accuracy: 0.8777 - adversarial_loss: 1.1213 - val_loss: 7.0359 - val_categorical_crossentropy: 5.5725 - val_categorical_accuracy: 0.2322 - val_adversarial_loss: 7.3169
# Epoch 15/100
# 89/89 - 4s - loss: 0.5797 - categorical_crossentropy: 0.3680 - categorical_accuracy: 0.8955 - adversarial_loss: 1.0585 - val_loss: 6.3501 - val_categorical_crossentropy: 5.0371 - val_categorical_accuracy: 0.2415 - val_adversarial_loss: 6.5649
# Epoch 16/100
# 89/89 - 4s - loss: 0.5568 - categorical_crossentropy: 0.3471 - categorical_accuracy: 0.8998 - adversarial_loss: 1.0486 - val_loss: 7.3533 - val_categorical_crossentropy: 5.8803 - val_categorical_accuracy: 0.2060 - val_adversarial_loss: 7.3653
# Epoch 17/100
# 89/89 - 4s - loss: 0.4868 - categorical_crossentropy: 0.2971 - categorical_accuracy: 0.9152 - adversarial_loss: 0.9481 - val_loss: 7.8054 - val_categorical_crossentropy: 6.2524 - val_categorical_accuracy: 0.2003 - val_adversarial_loss: 7.7650
# Epoch 18/100
# 89/89 - 4s - loss: 0.4375 - categorical_crossentropy: 0.2603 - categorical_accuracy: 0.9266 - adversarial_loss: 0.8863 - val_loss: 10.5560 - val_categorical_crossentropy: 8.4943 - val_categorical_accuracy: 0.1555 - val_adversarial_loss: 10.3084
# Epoch 19/100
# 89/89 - 4s - loss: 0.4002 - categorical_crossentropy: 0.2300 - categorical_accuracy: 0.9396 - adversarial_loss: 0.8509 - val_loss: 14.2762 - val_categorical_crossentropy: 11.5461 - val_categorical_accuracy: 0.1222 - val_adversarial_loss: 13.6501
# Epoch 20/100
# 89/89 - 4s - loss: 0.3440 - categorical_crossentropy: 0.1894 - categorical_accuracy: 0.9486 - adversarial_loss: 0.7730 - val_loss: 8.1795 - val_categorical_crossentropy: 6.5429 - val_categorical_accuracy: 0.1499 - val_adversarial_loss: 8.1833
# Epoch 21/100
# 89/89 - 4s - loss: 0.3143 - categorical_crossentropy: 0.1677 - categorical_accuracy: 0.9570 - adversarial_loss: 0.7328 - val_loss: 6.5855 - val_categorical_crossentropy: 5.2232 - val_categorical_accuracy: 0.2464 - val_adversarial_loss: 6.8112
# Epoch 22/100
# 89/89 - 4s - loss: 0.2868 - categorical_crossentropy: 0.1490 - categorical_accuracy: 0.9626 - adversarial_loss: 0.6889 - val_loss: 13.3578 - val_categorical_crossentropy: 10.7788 - val_categorical_accuracy: 0.1222 - val_adversarial_loss: 12.8950
# Epoch 23/100
# 89/89 - 4s - loss: 0.2735 - categorical_crossentropy: 0.1379 - categorical_accuracy: 0.9649 - adversarial_loss: 0.6782 - val_loss: 10.6339 - val_categorical_crossentropy: 8.5444 - val_categorical_accuracy: 0.1655 - val_adversarial_loss: 10.4476
# Epoch 24/100
# 89/89 - 4s - loss: 0.2613 - categorical_crossentropy: 0.1300 - categorical_accuracy: 0.9662 - adversarial_loss: 0.6568 - val_loss: 10.1880 - val_categorical_crossentropy: 8.2031 - val_categorical_accuracy: 0.1868 - val_adversarial_loss: 9.9244
# Epoch 25/100
# 89/89 - 4s - loss: 0.2546 - categorical_crossentropy: 0.1240 - categorical_accuracy: 0.9687 - adversarial_loss: 0.6533 - val_loss: 10.6176 - val_categorical_crossentropy: 8.5198 - val_categorical_accuracy: 0.2053 - val_adversarial_loss: 10.4891
# Epoch 26/100
# 89/89 - 4s - loss: 0.2725 - categorical_crossentropy: 0.1357 - categorical_accuracy: 0.9624 - adversarial_loss: 0.6843 - val_loss: 19.4402 - val_categorical_crossentropy: 15.7824 - val_categorical_accuracy: 0.1449 - val_adversarial_loss: 18.2891
# Epoch 27/100
# 89/89 - 4s - loss: 0.2322 - categorical_crossentropy: 0.1083 - categorical_accuracy: 0.9726 - adversarial_loss: 0.6193 - val_loss: 8.3030 - val_categorical_crossentropy: 6.6244 - val_categorical_accuracy: 0.1875 - val_adversarial_loss: 8.3931
# Epoch 28/100
# 89/89 - 4s - loss: 0.2121 - categorical_crossentropy: 0.0955 - categorical_accuracy: 0.9785 - adversarial_loss: 0.5830 - val_loss: 7.2180 - val_categorical_crossentropy: 5.6951 - val_categorical_accuracy: 0.2820 - val_adversarial_loss: 7.6146
# Epoch 29/100
# 89/89 - 4s - loss: 0.2031 - categorical_crossentropy: 0.0901 - categorical_accuracy: 0.9776 - adversarial_loss: 0.5650 - val_loss: 11.1966 - val_categorical_crossentropy: 8.9864 - val_categorical_accuracy: 0.2116 - val_adversarial_loss: 11.0513
# Epoch 30/100
# 89/89 - 4s - loss: 0.1897 - categorical_crossentropy: 0.0816 - categorical_accuracy: 0.9803 - adversarial_loss: 0.5406 - val_loss: 7.7849 - val_categorical_crossentropy: 6.1724 - val_categorical_accuracy: 0.2514 - val_adversarial_loss: 8.0625
# Epoch 31/100
# 89/89 - 4s - loss: 0.1878 - categorical_crossentropy: 0.0801 - categorical_accuracy: 0.9811 - adversarial_loss: 0.5387 - val_loss: 9.1522 - val_categorical_crossentropy: 7.2966 - val_categorical_accuracy: 0.2308 - val_adversarial_loss: 9.2783
# Epoch 32/100
# 89/89 - 4s - loss: 0.1517 - categorical_crossentropy: 0.0603 - categorical_accuracy: 0.9870 - adversarial_loss: 0.4568 - val_loss: 10.7153 - val_categorical_crossentropy: 8.5465 - val_categorical_accuracy: 0.2415 - val_adversarial_loss: 10.8445
# Epoch 33/100
# 89/89 - 4s - loss: 0.1187 - categorical_crossentropy: 0.0425 - categorical_accuracy: 0.9922 - adversarial_loss: 0.3807 - val_loss: 10.3850 - val_categorical_crossentropy: 8.2745 - val_categorical_accuracy: 0.2585 - val_adversarial_loss: 10.5524
# Epoch 34/100
# 89/89 - 4s - loss: 0.0965 - categorical_crossentropy: 0.0323 - categorical_accuracy: 0.9941 - adversarial_loss: 0.3213 - val_loss: 13.7531 - val_categorical_crossentropy: 11.0311 - val_categorical_accuracy: 0.2010 - val_adversarial_loss: 13.6099
# Epoch 35/100
# 89/89 - 4s - loss: 0.0774 - categorical_crossentropy: 0.0221 - categorical_accuracy: 0.9976 - adversarial_loss: 0.2763 - val_loss: 8.0393 - val_categorical_crossentropy: 6.3694 - val_categorical_accuracy: 0.2884 - val_adversarial_loss: 8.3497
# Epoch 36/100
# 89/89 - 4s - loss: 0.0735 - categorical_crossentropy: 0.0209 - categorical_accuracy: 0.9980 - adversarial_loss: 0.2630 - val_loss: 7.7589 - val_categorical_crossentropy: 6.1377 - val_categorical_accuracy: 0.2990 - val_adversarial_loss: 8.1064
# Epoch 37/100
# 89/89 - 4s - loss: 0.0592 - categorical_crossentropy: 0.0142 - categorical_accuracy: 0.9989 - adversarial_loss: 0.2254 - val_loss: 5.8973 - val_categorical_crossentropy: 4.5936 - val_categorical_accuracy: 0.3722 - val_adversarial_loss: 6.5181
# Epoch 38/100
# 89/89 - 4s - loss: 0.0486 - categorical_crossentropy: 0.0103 - categorical_accuracy: 0.9992 - adversarial_loss: 0.1913 - val_loss: 5.3583 - val_categorical_crossentropy: 4.1532 - val_categorical_accuracy: 0.3899 - val_adversarial_loss: 6.0258
# Epoch 39/100
# 89/89 - 4s - loss: 0.0435 - categorical_crossentropy: 0.0090 - categorical_accuracy: 0.9996 - adversarial_loss: 0.1726 - val_loss: 4.9520 - val_categorical_crossentropy: 3.8236 - val_categorical_accuracy: 0.4247 - val_adversarial_loss: 5.6419
# Epoch 40/100
# 89/89 - 4s - loss: 0.0378 - categorical_crossentropy: 0.0069 - categorical_accuracy: 0.9998 - adversarial_loss: 0.1548 - val_loss: 4.5598 - val_categorical_crossentropy: 3.4920 - val_categorical_accuracy: 0.4339 - val_adversarial_loss: 5.3390
# Epoch 41/100
# 89/89 - 4s - loss: 0.0325 - categorical_crossentropy: 0.0054 - categorical_accuracy: 0.9999 - adversarial_loss: 0.1357 - val_loss: 3.9458 - val_categorical_crossentropy: 3.0033 - val_categorical_accuracy: 0.5078 - val_adversarial_loss: 4.7128
# Epoch 42/100
# 89/89 - 4s - loss: 0.0282 - categorical_crossentropy: 0.0041 - categorical_accuracy: 1.0000 - adversarial_loss: 0.1201 - val_loss: 4.3782 - val_categorical_crossentropy: 3.3562 - val_categorical_accuracy: 0.4723 - val_adversarial_loss: 5.1101
# Epoch 43/100
# 89/89 - 4s - loss: 0.0234 - categorical_crossentropy: 0.0031 - categorical_accuracy: 1.0000 - adversarial_loss: 0.1015 - val_loss: 4.6435 - val_categorical_crossentropy: 3.5555 - val_categorical_accuracy: 0.4595 - val_adversarial_loss: 5.4400
# Epoch 44/100
# 89/89 - 4s - loss: 0.0186 - categorical_crossentropy: 0.0022 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0818 - val_loss: 5.2309 - val_categorical_crossentropy: 4.0209 - val_categorical_accuracy: 0.4460 - val_adversarial_loss: 6.0498
# Epoch 45/100
# 89/89 - 4s - loss: 0.0172 - categorical_crossentropy: 0.0023 - categorical_accuracy: 0.9997 - adversarial_loss: 0.0748 - val_loss: 4.8237 - val_categorical_crossentropy: 3.6926 - val_categorical_accuracy: 0.4673 - val_adversarial_loss: 5.6556
# Epoch 46/100
# 89/89 - 4s - loss: 0.0134 - categorical_crossentropy: 0.0014 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0599 - val_loss: 4.6720 - val_categorical_crossentropy: 3.5669 - val_categorical_accuracy: 0.4858 - val_adversarial_loss: 5.5259
# Epoch 47/100
# 89/89 - 4s - loss: 0.0120 - categorical_crossentropy: 0.0012 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0541 - val_loss: 4.1836 - val_categorical_crossentropy: 3.1676 - val_categorical_accuracy: 0.5185 - val_adversarial_loss: 5.0800
# Epoch 48/100
# 89/89 - 4s - loss: 0.0101 - categorical_crossentropy: 9.5368e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0455 - val_loss: 4.0618 - val_categorical_crossentropy: 3.0632 - val_categorical_accuracy: 0.5199 - val_adversarial_loss: 4.9927
# Epoch 49/100
# 89/89 - 4s - loss: 0.0083 - categorical_crossentropy: 7.6048e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0377 - val_loss: 3.9164 - val_categorical_crossentropy: 2.9516 - val_categorical_accuracy: 0.5355 - val_adversarial_loss: 4.8239
# Epoch 50/100
# 89/89 - 4s - loss: 0.0071 - categorical_crossentropy: 6.1388e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0324 - val_loss: 4.3636 - val_categorical_crossentropy: 3.3027 - val_categorical_accuracy: 0.5078 - val_adversarial_loss: 5.3043
# Epoch 51/100
# 89/89 - 4s - loss: 0.0062 - categorical_crossentropy: 5.3053e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0285 - val_loss: 4.5180 - val_categorical_crossentropy: 3.4210 - val_categorical_accuracy: 0.5078 - val_adversarial_loss: 5.4850
# Epoch 52/100
# 89/89 - 4s - loss: 0.0056 - categorical_crossentropy: 4.7063e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0257 - val_loss: 4.1759 - val_categorical_crossentropy: 3.1534 - val_categorical_accuracy: 0.5312 - val_adversarial_loss: 5.1123
# Epoch 53/100
# 89/89 - 4s - loss: 0.0052 - categorical_crossentropy: 4.1029e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0240 - val_loss: 4.2609 - val_categorical_crossentropy: 3.2136 - val_categorical_accuracy: 0.5234 - val_adversarial_loss: 5.2368
# Epoch 54/100
# 89/89 - 4s - loss: 0.0048 - categorical_crossentropy: 3.6089e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0220 - val_loss: 3.8956 - val_categorical_crossentropy: 2.9263 - val_categorical_accuracy: 0.5426 - val_adversarial_loss: 4.8463
# Epoch 55/100
# 89/89 - 4s - loss: 0.0044 - categorical_crossentropy: 3.2578e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0202 - val_loss: 3.7998 - val_categorical_crossentropy: 2.8446 - val_categorical_accuracy: 0.5554 - val_adversarial_loss: 4.7762
# Epoch 56/100
# 89/89 - 4s - loss: 0.0042 - categorical_crossentropy: 2.9818e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0194 - val_loss: 4.9568 - val_categorical_crossentropy: 3.7750 - val_categorical_accuracy: 0.4908 - val_adversarial_loss: 5.9094
# Epoch 57/100
# 89/89 - 4s - loss: 0.0042 - categorical_crossentropy: 2.9173e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0194 - val_loss: 4.7446 - val_categorical_crossentropy: 3.6008 - val_categorical_accuracy: 0.5128 - val_adversarial_loss: 5.7188
# Epoch 58/100
# 89/89 - 4s - loss: 0.0046 - categorical_crossentropy: 2.8811e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0213 - val_loss: 4.8546 - val_categorical_crossentropy: 3.6806 - val_categorical_accuracy: 0.5064 - val_adversarial_loss: 5.8702
# Epoch 59/100
# 89/89 - 4s - loss: 0.0053 - categorical_crossentropy: 3.1682e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0251 - val_loss: 3.4719 - val_categorical_crossentropy: 2.5745 - val_categorical_accuracy: 0.5668 - val_adversarial_loss: 4.4871
# Epoch 60/100
# 89/89 - 4s - loss: 0.0352 - categorical_crossentropy: 0.0110 - categorical_accuracy: 0.9972 - adversarial_loss: 0.1211 - val_loss: 10.4611 - val_categorical_crossentropy: 8.2957 - val_categorical_accuracy: 0.2422 - val_adversarial_loss: 10.8271
# Epoch 61/100
# 89/89 - 4s - loss: 2.1618 - categorical_crossentropy: 1.5830 - categorical_accuracy: 0.6320 - adversarial_loss: 2.8939 - val_loss: 11.3991 - val_categorical_crossentropy: 9.2148 - val_categorical_accuracy: 0.1435 - val_adversarial_loss: 10.9216
# Epoch 62/100
# 89/89 - 4s - loss: 0.8571 - categorical_crossentropy: 0.5942 - categorical_accuracy: 0.8145 - adversarial_loss: 1.3143 - val_loss: 8.0341 - val_categorical_crossentropy: 6.3477 - val_categorical_accuracy: 0.2841 - val_adversarial_loss: 8.4323
# Epoch 63/100
# 89/89 - 4s - loss: 0.2848 - categorical_crossentropy: 0.1579 - categorical_accuracy: 0.9593 - adversarial_loss: 0.6347 - val_loss: 10.5181 - val_categorical_crossentropy: 8.3976 - val_categorical_accuracy: 0.2479 - val_adversarial_loss: 10.6023
# Epoch 64/100
# 89/89 - 4s - loss: 0.1484 - categorical_crossentropy: 0.0647 - categorical_accuracy: 0.9885 - adversarial_loss: 0.4184 - val_loss: 7.9473 - val_categorical_crossentropy: 6.2829 - val_categorical_accuracy: 0.2884 - val_adversarial_loss: 8.3222
# Epoch 65/100
# 89/89 - 4s - loss: 0.0954 - categorical_crossentropy: 0.0335 - categorical_accuracy: 0.9959 - adversarial_loss: 0.3099 - val_loss: 9.2507 - val_categorical_crossentropy: 7.3434 - val_categorical_accuracy: 0.2692 - val_adversarial_loss: 9.5366
# Epoch 66/100
# 89/89 - 4s - loss: 0.0659 - categorical_crossentropy: 0.0191 - categorical_accuracy: 0.9982 - adversarial_loss: 0.2342 - val_loss: 5.0090 - val_categorical_crossentropy: 3.8759 - val_categorical_accuracy: 0.4197 - val_adversarial_loss: 5.6656
# Epoch 67/100
# 89/89 - 4s - loss: 0.0464 - categorical_crossentropy: 0.0106 - categorical_accuracy: 0.9996 - adversarial_loss: 0.1791 - val_loss: 4.3952 - val_categorical_crossentropy: 3.3497 - val_categorical_accuracy: 0.5107 - val_adversarial_loss: 5.2273
# Epoch 68/100
# 89/89 - 4s - loss: 0.0320 - categorical_crossentropy: 0.0057 - categorical_accuracy: 1.0000 - adversarial_loss: 0.1313 - val_loss: 3.7532 - val_categorical_crossentropy: 2.8323 - val_categorical_accuracy: 0.5149 - val_adversarial_loss: 4.6047
# Epoch 69/100
# 89/89 - 4s - loss: 0.0220 - categorical_crossentropy: 0.0032 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0936 - val_loss: 3.5893 - val_categorical_crossentropy: 2.6957 - val_categorical_accuracy: 0.5121 - val_adversarial_loss: 4.4676
# Epoch 70/100
# 89/89 - 4s - loss: 0.0164 - categorical_crossentropy: 0.0023 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0702 - val_loss: 3.1603 - val_categorical_crossentropy: 2.3530 - val_categorical_accuracy: 0.5625 - val_adversarial_loss: 4.0369
# Epoch 71/100
# 89/89 - 4s - loss: 0.0132 - categorical_crossentropy: 0.0017 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0574 - val_loss: 3.1501 - val_categorical_crossentropy: 2.3316 - val_categorical_accuracy: 0.5859 - val_adversarial_loss: 4.0925
# Epoch 72/100
# 89/89 - 4s - loss: 0.0107 - categorical_crossentropy: 0.0013 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0468 - val_loss: 2.9364 - val_categorical_crossentropy: 2.1636 - val_categorical_accuracy: 0.6108 - val_adversarial_loss: 3.8638
# Epoch 73/100
# 89/89 - 4s - loss: 0.0085 - categorical_crossentropy: 0.0010 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0371 - val_loss: 3.3574 - val_categorical_crossentropy: 2.4963 - val_categorical_accuracy: 0.5724 - val_adversarial_loss: 4.3052
# Epoch 74/100
# 89/89 - 4s - loss: 0.0067 - categorical_crossentropy: 8.1159e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0293 - val_loss: 3.5399 - val_categorical_crossentropy: 2.6325 - val_categorical_accuracy: 0.5689 - val_adversarial_loss: 4.5369
# Epoch 75/100
# 89/89 - 4s - loss: 0.0056 - categorical_crossentropy: 6.6618e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0246 - val_loss: 3.6548 - val_categorical_crossentropy: 2.7210 - val_categorical_accuracy: 0.5646 - val_adversarial_loss: 4.6688
# Epoch 76/100
# 89/89 - 4s - loss: 0.0048 - categorical_crossentropy: 5.6454e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0213 - val_loss: 3.4384 - val_categorical_crossentropy: 2.5487 - val_categorical_accuracy: 0.5881 - val_adversarial_loss: 4.4482
# Epoch 77/100
# 89/89 - 4s - loss: 0.0042 - categorical_crossentropy: 4.8398e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0185 - val_loss: 3.4696 - val_categorical_crossentropy: 2.5720 - val_categorical_accuracy: 0.5788 - val_adversarial_loss: 4.4881
# Epoch 78/100
# 89/89 - 4s - loss: 0.0037 - categorical_crossentropy: 4.2196e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0165 - val_loss: 3.3364 - val_categorical_crossentropy: 2.4617 - val_categorical_accuracy: 0.5980 - val_adversarial_loss: 4.3738
# Epoch 79/100
# 89/89 - 4s - loss: 0.0033 - categorical_crossentropy: 3.7437e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0149 - val_loss: 3.2806 - val_categorical_crossentropy: 2.4125 - val_categorical_accuracy: 0.6072 - val_adversarial_loss: 4.3402
# Epoch 80/100
# 89/89 - 4s - loss: 0.0029 - categorical_crossentropy: 3.2529e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0130 - val_loss: 2.9584 - val_categorical_crossentropy: 2.1603 - val_categorical_accuracy: 0.6328 - val_adversarial_loss: 3.9903
# Epoch 81/100
# 89/89 - 4s - loss: 0.0027 - categorical_crossentropy: 2.7816e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0120 - val_loss: 2.9242 - val_categorical_crossentropy: 2.1323 - val_categorical_accuracy: 0.6392 - val_adversarial_loss: 3.9593
# Epoch 82/100
# 89/89 - 4s - loss: 0.0024 - categorical_crossentropy: 2.4772e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0106 - val_loss: 3.1218 - val_categorical_crossentropy: 2.2877 - val_categorical_accuracy: 0.6229 - val_adversarial_loss: 4.1706
# Epoch 83/100
# 89/89 - 4s - loss: 0.0021 - categorical_crossentropy: 2.2171e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0093 - val_loss: 3.2531 - val_categorical_crossentropy: 2.3938 - val_categorical_accuracy: 0.6186 - val_adversarial_loss: 4.2962
# Epoch 84/100
# 89/89 - 4s - loss: 0.0018 - categorical_crossentropy: 1.9548e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0079 - val_loss: 3.1921 - val_categorical_crossentropy: 2.3481 - val_categorical_accuracy: 0.6236 - val_adversarial_loss: 4.2204
# Epoch 85/100
# 89/89 - 4s - loss: 0.0016 - categorical_crossentropy: 1.7714e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0071 - val_loss: 3.2183 - val_categorical_crossentropy: 2.3639 - val_categorical_accuracy: 0.6314 - val_adversarial_loss: 4.2720
# Epoch 86/100
# 89/89 - 4s - loss: 0.0014 - categorical_crossentropy: 1.5774e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0062 - val_loss: 3.2659 - val_categorical_crossentropy: 2.3974 - val_categorical_accuracy: 0.6307 - val_adversarial_loss: 4.3426
# Epoch 87/100
# 89/89 - 4s - loss: 0.0013 - categorical_crossentropy: 1.4312e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0057 - val_loss: 3.2477 - val_categorical_crossentropy: 2.3794 - val_categorical_accuracy: 0.6300 - val_adversarial_loss: 4.3413
# Epoch 88/100
# 89/89 - 4s - loss: 0.0012 - categorical_crossentropy: 1.2958e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0052 - val_loss: 3.1942 - val_categorical_crossentropy: 2.3363 - val_categorical_accuracy: 0.6399 - val_adversarial_loss: 4.2894
# Epoch 89/100
# 89/89 - 4s - loss: 0.0011 - categorical_crossentropy: 1.1797e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0047 - val_loss: 3.1898 - val_categorical_crossentropy: 2.3319 - val_categorical_accuracy: 0.6435 - val_adversarial_loss: 4.2894
# Epoch 90/100
# 89/89 - 4s - loss: 9.8116e-04 - categorical_crossentropy: 1.0778e-04 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0044 - val_loss: 3.1815 - val_categorical_crossentropy: 2.3251 - val_categorical_accuracy: 0.6470 - val_adversarial_loss: 4.2821
# Epoch 91/100
# 89/89 - 4s - loss: 9.0294e-04 - categorical_crossentropy: 9.8710e-05 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0040 - val_loss: 3.1666 - val_categorical_crossentropy: 2.3124 - val_categorical_accuracy: 0.6456 - val_adversarial_loss: 4.2713
# Epoch 92/100
# 89/89 - 4s - loss: 8.3420e-04 - categorical_crossentropy: 9.0562e-05 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0037 - val_loss: 3.1402 - val_categorical_crossentropy: 2.2908 - val_categorical_accuracy: 0.6484 - val_adversarial_loss: 4.2467
# Epoch 93/100
# 89/89 - 4s - loss: 7.7475e-04 - categorical_crossentropy: 8.3325e-05 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0035 - val_loss: 3.1205 - val_categorical_crossentropy: 2.2741 - val_categorical_accuracy: 0.6520 - val_adversarial_loss: 4.2320
# Epoch 94/100
# 89/89 - 4s - loss: 7.1971e-04 - categorical_crossentropy: 7.6755e-05 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0032 - val_loss: 3.1254 - val_categorical_crossentropy: 2.2770 - val_categorical_accuracy: 0.6506 - val_adversarial_loss: 4.2421
# Epoch 95/100
# 89/89 - 4s - loss: 6.6772e-04 - categorical_crossentropy: 7.0826e-05 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0030 - val_loss: 3.1227 - val_categorical_crossentropy: 2.2728 - val_categorical_accuracy: 0.6555 - val_adversarial_loss: 4.2495
# Epoch 96/100
# 89/89 - 4s - loss: 6.2351e-04 - categorical_crossentropy: 6.5631e-05 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0028 - val_loss: 3.1123 - val_categorical_crossentropy: 2.2631 - val_categorical_accuracy: 0.6555 - val_adversarial_loss: 4.2460
# Epoch 97/100
# 89/89 - 4s - loss: 5.8070e-04 - categorical_crossentropy: 6.0730e-05 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0026 - val_loss: 3.0776 - val_categorical_crossentropy: 2.2348 - val_categorical_accuracy: 0.6605 - val_adversarial_loss: 4.2144
# Epoch 98/100
# 89/89 - 4s - loss: 5.4048e-04 - categorical_crossentropy: 5.6267e-05 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0024 - val_loss: 3.0652 - val_categorical_crossentropy: 2.2244 - val_categorical_accuracy: 0.6619 - val_adversarial_loss: 4.2041
# Epoch 99/100
# 89/89 - 4s - loss: 5.0582e-04 - categorical_crossentropy: 5.2295e-05 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0023 - val_loss: 3.0383 - val_categorical_crossentropy: 2.2020 - val_categorical_accuracy: 0.6648 - val_adversarial_loss: 4.1815
# Epoch 100/100
# 89/89 - 4s - loss: 4.7227e-04 - categorical_crossentropy: 4.8623e-05 - categorical_accuracy: 1.0000 - adversarial_loss: 0.0021 - val_loss: 3.0101 - val_categorical_crossentropy: 2.1790 - val_categorical_accuracy: 0.6712 - val_adversarial_loss: 4.1557

# %%
scores3=adv_model.evaluate({'input':X_test3,'label':cy_test3})
print("Test accuracy: %.1f"%(scores3[2]*100.))
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 32, 32) for input Tensor("input_3:0", shape=(None, 32, 32), dtype=float32), but it was called on an input with incompatible shape (None, 1024).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 32) for input Tensor("input_3:0", shape=(None, 32, 32), dtype=float32), but it was called on an input with incompatible shape (None, 1024).
# 45/45 [==============================] - 0s 11ms/step - loss: 3.1134 - categorical_crossentropy: 2.2495 - categorical_accuracy: 0.6561 - adversarial_loss: 4.3197
# Test accuracy: 65.6
