# %% [markdown]
# ## Code Modules & Functions

# %%
import numpy as np,pandas as pd,pylab as pl
import h5py,torch,urllib,zipfile
from torchvision.datasets import MNIST as tmnist
from torchvision import transforms
from torch.utils.data import DataLoader as tdl
from torch.utils.data import Dataset as tds
import torch.nn.functional as tnnf
from sklearn.datasets import make_classification
from IPython.core.magic import register_line_magic
dev=torch.device("cuda:0" if torch.cuda.is_available() 
                 else "cpu")

# %%
def model_acc(model,data_loader,num_features):
    correct_preds,num_examples=0,0    
    for features,targets in data_loader:
        features=features.view(-1,num_features).to(dev)
        targets=targets.to(dev)
        logits,probs=model(features)
        _,pred_labels=torch.max(probs,1)
        num_examples+=targets.size(0)
        correct_preds+=(pred_labels==targets).sum()        
    return correct_preds.float()/num_examples*100

# %%
@register_line_magic
def print_acc(t):
    if t=='test':
        print('Test accuracy: %.4f%%'%\
        (model_acc(model,test_loader,num_features)))
    if t=='train':
        print('Train accuracy: %.4f%%'%\
        (model_acc(model,train_loader,num_features)))

# %%
@register_line_magic
def print_acc2(t):
    if t=='test':
        print('Test accuracy: %.4f%%'%\
        (model_acc(model,test_loader2,num_features2)))
    if t=='train':
        print('Train accuracy: %.4f%%'%\
        (model_acc(model,train_loader2,num_features2)))

# %%
@register_line_magic
def train_run(epochs):
    epochs=int(epochs)
    for epoch in range(epochs):
        for batch_ids,(features,targets) in enumerate(train_loader):        
            features=features.view(-1,num_features).to(dev)
            targets=targets.to(dev)
            logits,probs=model(features)
            cost=tnnf.cross_entropy(logits,targets)
            optimizer.zero_grad(); cost.backward()
            optimizer.step()
            if not batch_ids%300:
                print ('Epoch: %03d/%03d | Batch %03d/%03d | Cost: %.4f' 
                       %(epoch+1,epochs,batch_ids, 
                         len(train)//batch_size,cost))           
        with torch.set_grad_enabled(False):
            print('Epoch: %03d/%03d train accuracy: %.2f%%'%\
                  (epoch+1,epochs,model_acc(model,train_loader,
                                            num_features)))

# %%
@register_line_magic
def train_run2(epochs):
    epochs=int(epochs)
    for epoch in range(epochs):
        for batch_ids,(features,targets) in enumerate(train_loader2):        
            features=features.view(-1,num_features2).to(dev)
            targets=targets.to(dev)
            logits,probs=model(features)
            cost=tnnf.cross_entropy(logits,targets.long())
            optimizer.zero_grad(); cost.backward()
            optimizer.step()
            if not batch_ids%300:
                print ('Epoch: %03d/%03d | Batch %03d/%03d | Cost: %.4f' 
                       %(epoch+1,epochs,batch_ids, 
                         len(train2)//batch_size2,cost))           
        with torch.set_grad_enabled(False):
            print('Epoch: %03d/%03d train accuracy: %.2f%%'%\
                  (epoch+1,epochs,model_acc(model,train_loader2,
                                            num_features2)))

# %% [markdown]
# ## Data

# %%
random_seed=1; batch_size=64
train=tmnist(root='data',train=True,download=True,
            transform=transforms.ToTensor())
test=tmnist(root='data',train=False, 
            transform=transforms.ToTensor())
train_loader=tdl(dataset=train,shuffle=True, 
                 batch_size=batch_size)
test_loader=tdl(dataset=test,shuffle=False, 
                batch_size=batch_size)
for images,labels in train_loader:  
    print('Image dimensions: %s'%str(images.shape))
    print('Label dimensions: %s'%str(labels.shape))
    break
# Out:
# Image dimensions: torch.Size([64, 1, 28, 28])
# Label dimensions: torch.Size([64])

# %%
fpath='https://olgabelitskaya.github.io/'
zf='LetterColorImages_123.h5.zip'
input_file=urllib.request.urlopen(fpath+zf)
output_file=open(zf,'wb'); 
output_file.write(input_file.read())
output_file.close(); input_file.close()
zipf=zipfile.ZipFile(zf,'r')
zipf.extractall(''); zipf.close()
f=h5py.File(zf[:-4],'r')
keys=list(f.keys()); print(keys)
X=np.array(f[keys[1]],dtype='float32')/255
y=np.array(f[keys[2]],dtype='int32')-1
N=len(y); n=int(.2*N); batch_size=16
shuffle_ids=np.arange(N)
np.random.RandomState(23).shuffle(shuffle_ids)
X,y=X[shuffle_ids],y[shuffle_ids]
X_test,X_train=X[:n],X[n:]
y_test,y_train=y[:n],y[n:]
X_train.shape,y_train.shape
# Out:
# ['backgrounds', 'images', 'labels']
# ((11352, 32, 32, 3), (11352,))

# %%
random_seed=1; batch_size2=64
class TData(tds):
    def __init__(self,X,y):   
        self.X=torch.tensor(X,dtype=torch.float32)
        self.y=torch.tensor(y,dtype=torch.int32)
    def __getitem__(self,index):
        train_img,train_lbl=self.X[index],self.y[index]
        return train_img,train_lbl
    def __len__(self):
        return self.y.shape[0]
train2=TData(X_train,y_train)
test2=TData(X_test,y_test)
train_loader2=tdl(dataset=train2,batch_size=batch_size2,shuffle=True)
test_loader2=tdl(dataset=test2,batch_size=batch_size2,shuffle=False)
for images,labels in train_loader2:  
    print('Image dimensions: %s'%str(images.shape))
    print('Label dimensions: %s'%str(labels.shape))
    break
# Out:
# Image dimensions: torch.Size([64, 32, 32, 3])
# Label dimensions: torch.Size([64])

# %% [markdown]
# ## MLP

# %%
num_features=784; num_classes=10
hidden1=512; hidden2=256; hidden3=128
class MLP(torch.nn.Module):
    def __init__(self,num_features,num_classes):
        super(MLP, self).__init__()
        self.linear1=torch.nn.Linear(num_features,hidden1)
        self.linear1.weight.detach().normal_(0.,.1)
        self.linear1.bias.detach().zero_()
        self.linear2=torch.nn.Linear(hidden1,hidden2)
        self.linear2.weight.detach().normal_(0.,.1)
        self.linear2.bias.detach().zero_()
        self.linear3=torch.nn.Linear(hidden2,hidden3)
        self.linear3.weight.detach().normal_(0.,.1)
        self.linear3.bias.detach().zero_()
        self.linear_out=torch.nn.Linear(hidden3,num_classes)
        self.linear_out.weight.detach().normal_(0.,.1)
        self.linear_out.bias.detach().zero_()        
    def forward(self,x):
        y=self.linear1(x); y=tnnf.relu(y)
        y=self.linear2(y); y=tnnf.relu(y)
        y=self.linear3(y); y=tnnf.relu(y)
        logits=self.linear_out(y)
        probs=tnnf.log_softmax(logits,dim=1)
        return logits,probs   
torch.manual_seed(random_seed)
model=MLP(num_features=num_features,
          num_classes=num_classes)
model=model.to(dev); learning_rate=.01
optimizer=torch.optim.SGD(model.parameters(),lr=learning_rate)

# %%
# %train_run 20
# Out:
# Epoch: 001/020 | Batch 000/3750 | Cost: 3.0801
# Epoch: 001/020 | Batch 300/3750 | Cost: 0.5278
# Epoch: 001/020 | Batch 600/3750 | Cost: 0.3894
# Epoch: 001/020 | Batch 900/3750 | Cost: 0.2452
# Epoch: 001/020 train accuracy: 91.56%
# Epoch: 002/020 | Batch 000/3750 | Cost: 0.4965
# Epoch: 002/020 | Batch 300/3750 | Cost: 0.1878
# Epoch: 002/020 | Batch 600/3750 | Cost: 0.1800
# Epoch: 002/020 | Batch 900/3750 | Cost: 0.2359
# Epoch: 002/020 train accuracy: 93.43%
# Epoch: 003/020 | Batch 000/3750 | Cost: 0.1885
# Epoch: 003/020 | Batch 300/3750 | Cost: 0.3394
# Epoch: 003/020 | Batch 600/3750 | Cost: 0.3513
# Epoch: 003/020 | Batch 900/3750 | Cost: 0.1871
# Epoch: 003/020 train accuracy: 94.71%
# Epoch: 004/020 | Batch 000/3750 | Cost: 0.0816
# Epoch: 004/020 | Batch 300/3750 | Cost: 0.1878
# Epoch: 004/020 | Batch 600/3750 | Cost: 0.2105
# Epoch: 004/020 | Batch 900/3750 | Cost: 0.1162
# Epoch: 004/020 train accuracy: 95.37%
# Epoch: 005/020 | Batch 000/3750 | Cost: 0.1774
# Epoch: 005/020 | Batch 300/3750 | Cost: 0.0962
# Epoch: 005/020 | Batch 600/3750 | Cost: 0.3447
# Epoch: 005/020 | Batch 900/3750 | Cost: 0.1360
# Epoch: 005/020 train accuracy: 96.03%
# Epoch: 006/020 | Batch 000/3750 | Cost: 0.1014
# Epoch: 006/020 | Batch 300/3750 | Cost: 0.0302
# Epoch: 006/020 | Batch 600/3750 | Cost: 0.1779
# Epoch: 006/020 | Batch 900/3750 | Cost: 0.1421
# Epoch: 006/020 train accuracy: 96.31%
# Epoch: 007/020 | Batch 000/3750 | Cost: 0.2343
# Epoch: 007/020 | Batch 300/3750 | Cost: 0.2093
# Epoch: 007/020 | Batch 600/3750 | Cost: 0.0687
# Epoch: 007/020 | Batch 900/3750 | Cost: 0.1147
# Epoch: 007/020 train accuracy: 96.58%
# Epoch: 008/020 | Batch 000/3750 | Cost: 0.1551
# Epoch: 008/020 | Batch 300/3750 | Cost: 0.0607
# Epoch: 008/020 | Batch 600/3750 | Cost: 0.1994
# Epoch: 008/020 | Batch 900/3750 | Cost: 0.0733
# Epoch: 008/020 train accuracy: 97.28%
# Epoch: 009/020 | Batch 000/3750 | Cost: 0.1624
# Epoch: 009/020 | Batch 300/3750 | Cost: 0.0581
# Epoch: 009/020 | Batch 600/3750 | Cost: 0.0795
# Epoch: 009/020 | Batch 900/3750 | Cost: 0.1198
# Epoch: 009/020 train accuracy: 97.28%
# Epoch: 010/020 | Batch 000/3750 | Cost: 0.0812
# Epoch: 010/020 | Batch 300/3750 | Cost: 0.1494
# Epoch: 010/020 | Batch 600/3750 | Cost: 0.0448
# Epoch: 010/020 | Batch 900/3750 | Cost: 0.0352
# Epoch: 010/020 train accuracy: 97.66%
# Epoch: 011/020 | Batch 000/3750 | Cost: 0.1209
# Epoch: 011/020 | Batch 300/3750 | Cost: 0.1843
# Epoch: 011/020 | Batch 600/3750 | Cost: 0.0493
# Epoch: 011/020 | Batch 900/3750 | Cost: 0.0534
# Epoch: 011/020 train accuracy: 97.93%
# Epoch: 012/020 | Batch 000/3750 | Cost: 0.1626
# Epoch: 012/020 | Batch 300/3750 | Cost: 0.0309
# Epoch: 012/020 | Batch 600/3750 | Cost: 0.1616
# Epoch: 012/020 | Batch 900/3750 | Cost: 0.0254
# Epoch: 012/020 train accuracy: 98.10%
# Epoch: 013/020 | Batch 000/3750 | Cost: 0.0784
# Epoch: 013/020 | Batch 300/3750 | Cost: 0.0935
# Epoch: 013/020 | Batch 600/3750 | Cost: 0.0479
# Epoch: 013/020 | Batch 900/3750 | Cost: 0.1233
# Epoch: 013/020 train accuracy: 98.21%
# Epoch: 014/020 | Batch 000/3750 | Cost: 0.0360
# Epoch: 014/020 | Batch 300/3750 | Cost: 0.0427
# Epoch: 014/020 | Batch 600/3750 | Cost: 0.0620
# Epoch: 014/020 | Batch 900/3750 | Cost: 0.0711
# Epoch: 014/020 train accuracy: 98.43%
# Epoch: 015/020 | Batch 000/3750 | Cost: 0.0160
# Epoch: 015/020 | Batch 300/3750 | Cost: 0.0406
# Epoch: 015/020 | Batch 600/3750 | Cost: 0.0890
# Epoch: 015/020 | Batch 900/3750 | Cost: 0.0304
# Epoch: 015/020 train accuracy: 98.43%
# Epoch: 016/020 | Batch 000/3750 | Cost: 0.0844
# Epoch: 016/020 | Batch 300/3750 | Cost: 0.0352
# Epoch: 016/020 | Batch 600/3750 | Cost: 0.0228
# Epoch: 016/020 | Batch 900/3750 | Cost: 0.2238
# Epoch: 016/020 train accuracy: 98.62%
# Epoch: 017/020 | Batch 000/3750 | Cost: 0.0201
# Epoch: 017/020 | Batch 300/3750 | Cost: 0.0183
# Epoch: 017/020 | Batch 600/3750 | Cost: 0.0282
# Epoch: 017/020 | Batch 900/3750 | Cost: 0.0616
# Epoch: 017/020 train accuracy: 98.85%
# Epoch: 018/020 | Batch 000/3750 | Cost: 0.0146
# Epoch: 018/020 | Batch 300/3750 | Cost: 0.0368
# Epoch: 018/020 | Batch 600/3750 | Cost: 0.0149
# Epoch: 018/020 | Batch 900/3750 | Cost: 0.0713
# Epoch: 018/020 train accuracy: 98.88%
# Epoch: 019/020 | Batch 000/3750 | Cost: 0.0187
# Epoch: 019/020 | Batch 300/3750 | Cost: 0.0131
# Epoch: 019/020 | Batch 600/3750 | Cost: 0.0428
# Epoch: 019/020 | Batch 900/3750 | Cost: 0.0112
# Epoch: 019/020 train accuracy: 98.80%
# Epoch: 020/020 | Batch 000/3750 | Cost: 0.0107
# Epoch: 020/020 | Batch 300/3750 | Cost: 0.0620
# Epoch: 020/020 | Batch 600/3750 | Cost: 0.0452
# Epoch: 020/020 | Batch 900/3750 | Cost: 0.0305
# Epoch: 020/020 train accuracy: 99.07%

# %%
# %print_acc train
# %print_acc test
# Out:
# Train accuracy: 99.0717%
# Test accuracy: 97.1900%

# %%
num_features2=3072; num_classes2=33
hidden1=1024; hidden2=256; hidden3=256
class MLP2(torch.nn.Module):
    def __init__(self,num_features,num_classes):
        super(MLP2, self).__init__()
        self.linear1=torch.nn.Linear(num_features,hidden1)
        self.linear1.weight.detach().normal_(0.,.1)
        self.linear1.bias.detach().zero_()
        self.linear2=torch.nn.Linear(hidden1,hidden2)
        self.linear2.weight.detach().normal_(0.,.1)
        self.linear2.bias.detach().zero_()
        self.linear3=torch.nn.Linear(hidden2,hidden3)
        self.linear3.weight.detach().normal_(0.,.1)
        self.linear3.bias.detach().zero_()
        self.linear_out=torch.nn.Linear(hidden3,num_classes)
        self.linear_out.weight.detach().normal_(0.,.1)
        self.linear_out.bias.detach().zero_()        
    def forward(self,x):
        y=self.linear1(x); y=tnnf.relu(y)
        y=self.linear2(y); y=tnnf.relu(y)
        y=self.linear3(y); y=tnnf.relu(y)
        logits=self.linear_out(y)
        probs=tnnf.log_softmax(logits,dim=1)
        return logits,probs   
torch.manual_seed(random_seed)
model=MLP2(num_features=num_features2,
           num_classes=num_classes2)
model=model.to(dev); learning_rate=.001
optimizer=torch.optim.SGD(model.parameters(),lr=learning_rate)

# %%
# %train_run2 30
# Out:
# Epoch: 001/030 | Batch 000/177 | Cost: 18.8860
# Epoch: 001/030 train accuracy: 4.44%
# Epoch: 002/030 | Batch 000/177 | Cost: 3.6305
# Epoch: 002/030 train accuracy: 5.10%
# Epoch: 003/030 | Batch 000/177 | Cost: 3.6215
# Epoch: 003/030 train accuracy: 5.41%
# Epoch: 004/030 | Batch 000/177 | Cost: 3.7901
# Epoch: 004/030 train accuracy: 7.11%
# Epoch: 005/030 | Batch 000/177 | Cost: 3.5122
# Epoch: 005/030 train accuracy: 4.83%
# Epoch: 006/030 | Batch 000/177 | Cost: 3.7561
# Epoch: 006/030 train accuracy: 6.56%
# Epoch: 007/030 | Batch 000/177 | Cost: 3.6580
# Epoch: 007/030 train accuracy: 10.64%
# Epoch: 008/030 | Batch 000/177 | Cost: 3.1447
# Epoch: 008/030 train accuracy: 5.76%
# Epoch: 009/030 | Batch 000/177 | Cost: 3.7092
# Epoch: 009/030 train accuracy: 11.58%
# Epoch: 010/030 | Batch 000/177 | Cost: 2.9794
# Epoch: 010/030 train accuracy: 13.61%
# Epoch: 011/030 | Batch 000/177 | Cost: 3.0264
# Epoch: 011/030 train accuracy: 12.83%
# Epoch: 012/030 | Batch 000/177 | Cost: 3.1623
# Epoch: 012/030 train accuracy: 13.98%
# Epoch: 013/030 | Batch 000/177 | Cost: 3.0518
# Epoch: 013/030 train accuracy: 10.16%
# Epoch: 014/030 | Batch 000/177 | Cost: 3.5482
# Epoch: 014/030 train accuracy: 15.70%
# Epoch: 015/030 | Batch 000/177 | Cost: 3.1491
# Epoch: 015/030 train accuracy: 11.58%
# Epoch: 016/030 | Batch 000/177 | Cost: 3.4668
# Epoch: 016/030 train accuracy: 14.47%
# Epoch: 017/030 | Batch 000/177 | Cost: 3.2110
# Epoch: 017/030 train accuracy: 16.19%
# Epoch: 018/030 | Batch 000/177 | Cost: 2.8796
# Epoch: 018/030 train accuracy: 16.34%
# Epoch: 019/030 | Batch 000/177 | Cost: 2.7955
# Epoch: 019/030 train accuracy: 18.84%
# Epoch: 020/030 | Batch 000/177 | Cost: 2.9279
# Epoch: 020/030 train accuracy: 17.13%
# Epoch: 021/030 | Batch 000/177 | Cost: 3.0829
# Epoch: 021/030 train accuracy: 19.65%
# Epoch: 022/030 | Batch 000/177 | Cost: 2.6954
# Epoch: 022/030 train accuracy: 20.74%
# Epoch: 023/030 | Batch 000/177 | Cost: 2.7086
# Epoch: 023/030 train accuracy: 23.57%
# Epoch: 024/030 | Batch 000/177 | Cost: 2.9082
# Epoch: 024/030 train accuracy: 19.15%
# Epoch: 025/030 | Batch 000/177 | Cost: 2.6057
# Epoch: 025/030 train accuracy: 17.38%
# Epoch: 026/030 | Batch 000/177 | Cost: 2.7893
# Epoch: 026/030 train accuracy: 22.84%
# Epoch: 027/030 | Batch 000/177 | Cost: 2.7170
# Epoch: 027/030 train accuracy: 23.00%
# Epoch: 028/030 | Batch 000/177 | Cost: 2.7912
# Epoch: 028/030 train accuracy: 24.19%
# Epoch: 029/030 | Batch 000/177 | Cost: 2.4999
# Epoch: 029/030 train accuracy: 26.87%
# Epoch: 030/030 | Batch 000/177 | Cost: 2.5852
# Epoch: 030/030 train accuracy: 22.42%

# %%
# %print_acc2 train
# %print_acc2 test
# Out:
# Train accuracy: 22.4190%
# Test accuracy: 20.9302%

# %% [markdown]
# ## MLP with Dropouts

# %%
num_features=784; num_classes=10
hidden1=1024; hidden2=256; hidden3=64
dropout_prob=.1
class MLPD(torch.nn.Module):
    def __init__(self,num_features,num_classes):
        super(MLPD,self).__init__()
        self.linear1=torch.nn.Linear(num_features,hidden1)
        self.linear1.weight.detach().normal_(0.,.1)
        self.linear1.bias.detach().zero_()
        self.linear2=torch.nn.Linear(hidden1,hidden2)
        self.linear2.weight.detach().normal_(0.,.1)
        self.linear2.bias.detach().zero_()
        self.linear3=torch.nn.Linear(hidden2,hidden3)
        self.linear3.weight.detach().normal_(0.,.1)
        self.linear3.bias.detach().zero_()
        self.linear_out=torch.nn.Linear(hidden3,num_classes)
        self.linear_out.weight.detach().normal_(0.,.1)
        self.linear_out.bias.detach().zero_()        
    def forward(self,x):
        y=self.linear1(x); y=tnnf.relu(y)
        y=tnnf.dropout(y,p=dropout_prob,
                       training=self.training)
        y=self.linear2(y); y=tnnf.relu(y)
        y=tnnf.dropout(y,p=dropout_prob,
                       training=self.training)
        y=self.linear3(y); y=tnnf.relu(y)
        logits=self.linear_out(y)
        probs=tnnf.log_softmax(logits,dim=1)
        return logits,probs   
torch.manual_seed(random_seed)
model=MLPD(num_features=num_features,
           num_classes=num_classes)
model=model.to(dev); learning_rate=.01
optimizer=torch.optim.SGD(model.parameters(),lr=learning_rate)

# %%
# %train_run 20
# Out:
# Epoch: 001/020 | Batch 000/3750 | Cost: 2.6523
# Epoch: 001/020 | Batch 300/3750 | Cost: 0.3704
# Epoch: 001/020 | Batch 600/3750 | Cost: 0.5917
# Epoch: 001/020 | Batch 900/3750 | Cost: 0.2443
# Epoch: 001/020 train accuracy: 88.26%
# Epoch: 002/020 | Batch 000/3750 | Cost: 0.6558
# Epoch: 002/020 | Batch 300/3750 | Cost: 0.2777
# Epoch: 002/020 | Batch 600/3750 | Cost: 0.2195
# Epoch: 002/020 | Batch 900/3750 | Cost: 0.3731
# Epoch: 002/020 train accuracy: 90.86%
# Epoch: 003/020 | Batch 000/3750 | Cost: 0.3805
# Epoch: 003/020 | Batch 300/3750 | Cost: 0.2315
# Epoch: 003/020 | Batch 600/3750 | Cost: 0.4046
# Epoch: 003/020 | Batch 900/3750 | Cost: 0.3105
# Epoch: 003/020 train accuracy: 92.52%
# Epoch: 004/020 | Batch 000/3750 | Cost: 0.1889
# Epoch: 004/020 | Batch 300/3750 | Cost: 0.2488
# Epoch: 004/020 | Batch 600/3750 | Cost: 0.1060
# Epoch: 004/020 | Batch 900/3750 | Cost: 0.5468
# Epoch: 004/020 train accuracy: 93.20%
# Epoch: 005/020 | Batch 000/3750 | Cost: 0.2749
# Epoch: 005/020 | Batch 300/3750 | Cost: 0.2196
# Epoch: 005/020 | Batch 600/3750 | Cost: 0.1666
# Epoch: 005/020 | Batch 900/3750 | Cost: 0.1655
# Epoch: 005/020 train accuracy: 93.95%
# Epoch: 006/020 | Batch 000/3750 | Cost: 0.1477
# Epoch: 006/020 | Batch 300/3750 | Cost: 0.1134
# Epoch: 006/020 | Batch 600/3750 | Cost: 0.2984
# Epoch: 006/020 | Batch 900/3750 | Cost: 0.1875
# Epoch: 006/020 train accuracy: 94.61%
# Epoch: 007/020 | Batch 000/3750 | Cost: 0.1199
# Epoch: 007/020 | Batch 300/3750 | Cost: 0.1949
# Epoch: 007/020 | Batch 600/3750 | Cost: 0.1622
# Epoch: 007/020 | Batch 900/3750 | Cost: 0.2796
# Epoch: 007/020 train accuracy: 94.98%
# Epoch: 008/020 | Batch 000/3750 | Cost: 0.1615
# Epoch: 008/020 | Batch 300/3750 | Cost: 0.3024
# Epoch: 008/020 | Batch 600/3750 | Cost: 0.1494
# Epoch: 008/020 | Batch 900/3750 | Cost: 0.1083
# Epoch: 008/020 train accuracy: 95.31%
# Epoch: 009/020 | Batch 000/3750 | Cost: 0.1009
# Epoch: 009/020 | Batch 300/3750 | Cost: 0.0993
# Epoch: 009/020 | Batch 600/3750 | Cost: 0.2581
# Epoch: 009/020 | Batch 900/3750 | Cost: 0.1636
# Epoch: 009/020 train accuracy: 95.47%
# Epoch: 010/020 | Batch 000/3750 | Cost: 0.1055
# Epoch: 010/020 | Batch 300/3750 | Cost: 0.0779
# Epoch: 010/020 | Batch 600/3750 | Cost: 0.1948
# Epoch: 010/020 | Batch 900/3750 | Cost: 0.0963
# Epoch: 010/020 train accuracy: 95.90%
# Epoch: 011/020 | Batch 000/3750 | Cost: 0.1168
# Epoch: 011/020 | Batch 300/3750 | Cost: 0.1869
# Epoch: 011/020 | Batch 600/3750 | Cost: 0.0726
# Epoch: 011/020 | Batch 900/3750 | Cost: 0.1470
# Epoch: 011/020 train accuracy: 96.04%
# Epoch: 012/020 | Batch 000/3750 | Cost: 0.0618
# Epoch: 012/020 | Batch 300/3750 | Cost: 0.0937
# Epoch: 012/020 | Batch 600/3750 | Cost: 0.1306
# Epoch: 012/020 | Batch 900/3750 | Cost: 0.0770
# Epoch: 012/020 train accuracy: 96.28%
# Epoch: 013/020 | Batch 000/3750 | Cost: 0.1074
# Epoch: 013/020 | Batch 300/3750 | Cost: 0.1150
# Epoch: 013/020 | Batch 600/3750 | Cost: 0.1833
# Epoch: 013/020 | Batch 900/3750 | Cost: 0.1305
# Epoch: 013/020 train accuracy: 96.62%
# Epoch: 014/020 | Batch 000/3750 | Cost: 0.1780
# Epoch: 014/020 | Batch 300/3750 | Cost: 0.2127
# Epoch: 014/020 | Batch 600/3750 | Cost: 0.1311
# Epoch: 014/020 | Batch 900/3750 | Cost: 0.0795
# Epoch: 014/020 train accuracy: 96.60%
# Epoch: 015/020 | Batch 000/3750 | Cost: 0.1482
# Epoch: 015/020 | Batch 300/3750 | Cost: 0.1669
# Epoch: 015/020 | Batch 600/3750 | Cost: 0.1841
# Epoch: 015/020 | Batch 900/3750 | Cost: 0.2530
# Epoch: 015/020 train accuracy: 96.93%
# Epoch: 016/020 | Batch 000/3750 | Cost: 0.1535
# Epoch: 016/020 | Batch 300/3750 | Cost: 0.0958
# Epoch: 016/020 | Batch 600/3750 | Cost: 0.1771
# Epoch: 016/020 | Batch 900/3750 | Cost: 0.0582
# Epoch: 016/020 train accuracy: 96.76%
# Epoch: 017/020 | Batch 000/3750 | Cost: 0.0866
# Epoch: 017/020 | Batch 300/3750 | Cost: 0.2647
# Epoch: 017/020 | Batch 600/3750 | Cost: 0.0217
# Epoch: 017/020 | Batch 900/3750 | Cost: 0.0789
# Epoch: 017/020 train accuracy: 97.09%
# Epoch: 018/020 | Batch 000/3750 | Cost: 0.1017
# Epoch: 018/020 | Batch 300/3750 | Cost: 0.0960
# Epoch: 018/020 | Batch 600/3750 | Cost: 0.1320
# Epoch: 018/020 | Batch 900/3750 | Cost: 0.0900
# Epoch: 018/020 train accuracy: 97.19%
# Epoch: 019/020 | Batch 000/3750 | Cost: 0.0486
# Epoch: 019/020 | Batch 300/3750 | Cost: 0.0300
# Epoch: 019/020 | Batch 600/3750 | Cost: 0.0814
# Epoch: 019/020 | Batch 900/3750 | Cost: 0.1091
# Epoch: 019/020 train accuracy: 97.36%
# Epoch: 020/020 | Batch 000/3750 | Cost: 0.0588
# Epoch: 020/020 | Batch 300/3750 | Cost: 0.0555
# Epoch: 020/020 | Batch 600/3750 | Cost: 0.0611
# Epoch: 020/020 | Batch 900/3750 | Cost: 0.0938
# Epoch: 020/020 train accuracy: 97.48%

# %%
# %print_acc train
# %print_acc test
# Out:
# Train accuracy: 97.4167%
# Test accuracy: 96.4900%

# %%
num_features2=3072; num_classes2=33
hidden1=hidden2=1024; hidden3=hidden4=256
dropout_prob2=.5
class MLPD2(torch.nn.Module):
    def __init__(self,num_features,num_classes):
        super(MLPD2,self).__init__()
        self.linear1=torch.nn.Linear(num_features,hidden1)
        self.linear1.weight.detach().normal_(0.,.1)
        self.linear1.bias.detach().zero_()
        self.linear2=torch.nn.Linear(hidden1,hidden2)
        self.linear2.weight.detach().normal_(0.,.1)
        self.linear2.bias.detach().zero_()
        self.linear3=torch.nn.Linear(hidden2,hidden3)
        self.linear3.weight.detach().normal_(0.,.1)
        self.linear3.bias.detach().zero_()
        self.linear4=torch.nn.Linear(hidden3,hidden4)
        self.linear4.weight.detach().normal_(0.,.1)
        self.linear4.bias.detach().zero_()
        self.linear_out=torch.nn.Linear(hidden4,num_classes)
        self.linear_out.weight.detach().normal_(0.,.1)
        self.linear_out.bias.detach().zero_()        
    def forward(self,x):
        y=self.linear1(x); y=tnnf.relu(y)
        y=self.linear2(y); y=tnnf.relu(y)
        y=tnnf.dropout(y,p=dropout_prob2,
                       training=self.training)
        y=self.linear3(y); y=tnnf.relu(y)
        y=self.linear4(y); y=tnnf.relu(y)
        logits=self.linear_out(y)
        probs=tnnf.log_softmax(logits,dim=1)
        return logits,probs   
torch.manual_seed(random_seed)
model=MLPD2(num_features=num_features2,
            num_classes=num_classes2)
model=model.to(dev); learning_rate=.005
optimizer=torch.optim.SGD(model.parameters(),lr=learning_rate)

# %%
# %train_run2 30
# Out:
# Epoch: 001/030 | Batch 000/177 | Cost: 60.9865
# Epoch: 001/030 train accuracy: 3.84%
# Epoch: 002/030 | Batch 000/177 | Cost: 3.5232
# Epoch: 002/030 train accuracy: 3.86%
# Epoch: 003/030 | Batch 000/177 | Cost: 3.5449
# Epoch: 003/030 train accuracy: 4.18%
# Epoch: 004/030 | Batch 000/177 | Cost: 3.5958
# Epoch: 004/030 train accuracy: 4.76%
# Epoch: 005/030 | Batch 000/177 | Cost: 3.5048
# Epoch: 005/030 train accuracy: 5.36%
# Epoch: 006/030 | Batch 000/177 | Cost: 3.4806
# Epoch: 006/030 train accuracy: 5.58%
# Epoch: 007/030 | Batch 000/177 | Cost: 3.4423
# Epoch: 007/030 train accuracy: 5.88%
# Epoch: 008/030 | Batch 000/177 | Cost: 3.3792
# Epoch: 008/030 train accuracy: 6.52%
# Epoch: 009/030 | Batch 000/177 | Cost: 3.2571
# Epoch: 009/030 train accuracy: 7.14%
# Epoch: 010/030 | Batch 000/177 | Cost: 3.3885
# Epoch: 010/030 train accuracy: 8.04%
# Epoch: 011/030 | Batch 000/177 | Cost: 3.4378
# Epoch: 011/030 train accuracy: 8.50%
# Epoch: 012/030 | Batch 000/177 | Cost: 3.4758
# Epoch: 012/030 train accuracy: 7.80%
# Epoch: 013/030 | Batch 000/177 | Cost: 3.1570
# Epoch: 013/030 train accuracy: 10.17%
# Epoch: 014/030 | Batch 000/177 | Cost: 3.2134
# Epoch: 014/030 train accuracy: 8.21%
# Epoch: 015/030 | Batch 000/177 | Cost: 3.4829
# Epoch: 015/030 train accuracy: 11.03%
# Epoch: 016/030 | Batch 000/177 | Cost: 3.1272
# Epoch: 016/030 train accuracy: 11.66%
# Epoch: 017/030 | Batch 000/177 | Cost: 3.1411
# Epoch: 017/030 train accuracy: 12.14%
# Epoch: 018/030 | Batch 000/177 | Cost: 2.9112
# Epoch: 018/030 train accuracy: 9.57%
# Epoch: 019/030 | Batch 000/177 | Cost: 3.2601
# Epoch: 019/030 train accuracy: 8.98%
# Epoch: 020/030 | Batch 000/177 | Cost: 3.2800
# Epoch: 020/030 train accuracy: 14.30%
# Epoch: 021/030 | Batch 000/177 | Cost: 3.0517
# Epoch: 021/030 train accuracy: 15.10%
# Epoch: 022/030 | Batch 000/177 | Cost: 3.0240
# Epoch: 022/030 train accuracy: 14.95%
# Epoch: 023/030 | Batch 000/177 | Cost: 2.9086
# Epoch: 023/030 train accuracy: 13.94%
# Epoch: 024/030 | Batch 000/177 | Cost: 3.0763
# Epoch: 024/030 train accuracy: 10.85%
# Epoch: 025/030 | Batch 000/177 | Cost: 3.1878
# Epoch: 025/030 train accuracy: 13.17%
# Epoch: 026/030 | Batch 000/177 | Cost: 3.0182
# Epoch: 026/030 train accuracy: 11.92%
# Epoch: 027/030 | Batch 000/177 | Cost: 3.5933
# Epoch: 027/030 train accuracy: 17.16%
# Epoch: 028/030 | Batch 000/177 | Cost: 2.5617
# Epoch: 028/030 train accuracy: 18.28%
# Epoch: 029/030 | Batch 000/177 | Cost: 2.9262
# Epoch: 029/030 train accuracy: 16.44%
# Epoch: 030/030 | Batch 000/177 | Cost: 2.8445
# Epoch: 030/030 train accuracy: 14.39%

# %%
# %print_acc2 train
# %print_acc2 test
# Out:
# Train accuracy: 14.2178%
# Test accuracy: 13.3545%
