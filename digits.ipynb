# %% [markdown]
# # Libraries & Functions

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %%
import time,pandas,numpy,pylab,keras,sklearn
from keras.datasets import mnist
from sklearn import datasets
from scipy import stats
pylab.style.use('seaborn-whitegrid')
import warnings; warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
from sklearn import svm,manifold,linear_model
from sklearn.semi_supervised import label_propagation
from sklearn.linear_model import LogisticRegressionCV
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,hamming_loss
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import RadiusNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier,BernoulliRBM

# %%
from keras.models import Sequential,Model
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Conv1D,Conv2D,MaxPooling1D,MaxPooling2D
from keras.layers import GlobalAveragePooling2D,GlobalMaxPooling2D
from keras.layers.advanced_activations import PReLU,LeakyReLU
from keras.layers import Input,Dense,LSTM,Dropout
from keras.layers import BatchNormalization,Activation,Flatten

# %%
def clf_fit_score(clf,x_train,x_test,y_train,y_test):
    clf.fit(x_train,y_train)    
    y_clf_train=clf.predict(x_train)
    y_clf_test=clf.predict(x_test)        
    acc_clf_train=\
    round(accuracy_score(y_train,y_clf_train),6)
    acc_clf_test=\
    round(accuracy_score(y_test,y_clf_test),6)   
    loss_clf_train=\
    round(hamming_loss(y_train,y_clf_train),6)
    loss_clf_test=\
    round(hamming_loss(y_test,y_clf_test),6)   
    return [str(clf),y_clf_train,y_clf_test,
            acc_clf_train,acc_clf_test,
            loss_clf_train,loss_clf_test]

# %%
def history_plot(fit_history):
    pylab.figure(figsize=(12,10)); pylab.subplot(211)
    keys=list(fit_history.history.keys())[0:4]
    pylab.plot(fit_history.history[keys[0]],
               color='slategray',label='train')
    pylab.plot(fit_history.history[keys[2]],
               color='steelblue',label='valid')
    pylab.xlabel("Epochs"); pylab.ylabel("Loss")
    pylab.legend(); pylab.grid(); pylab.title('Loss Function')     
    pylab.subplot(212)
    pylab.plot(fit_history.history[keys[1]],
               color='slategray',label='train')
    pylab.plot(fit_history.history[keys[3]],
               color='steelblue',label='valid')
    pylab.xlabel("Epochs"); pylab.ylabel("Accuracy")    
    pylab.legend(); pylab.grid()
    pylab.title('Accuracy'); pylab.show()

# %% [markdown]
# # Datasets

# %%
# 8x8 grayscale images; labeled over 10 categories
digits=datasets.load_digits()
X,y=digits.data,digits.target
[x_train1,x_test1,y_train1,y_test1]=\
train_test_split(X,y,test_size=0.2,random_state=1)
n=4; img=numpy.zeros((10*n,10*n))
for i in range(n): 
    for j in range(n): 
      img[(10*i+1):(10*i+9),(10*j+1):(10*j+9)]=\
      X[i*n+j].reshape((8,8))
pylab.figure(figsize=(5,5))
pylab.imshow(img,cmap=pylab.cm.bone)
pylab.title('Examples of 64-dimensional digits')
pylab.xticks([]); pylab.yticks([]); pylab.show()

# %%
t0=time.time()
X_emb=manifold.TSNE(n_components=2,learning_rate=700.0)\
              .fit_transform(X)
x_min,x_max=numpy.min(X_emb,0),numpy.max(X_emb,0)
X_emb=(X_emb-x_min)/(x_max-x_min)
f,ax=pylab.subplots(1,figsize=(12,5))
pylab.axis("off")
for i in range(X_emb.shape[0]):
    pylab.text(X_emb[i,0],X_emb[i,1],str(y[i]),
               color=pylab.cm.hsv(y[i]/10.))
pylab.title("t-SNE embedding %f s"%(time.time()-t0))
pylab.show()

# %%
# 28x28 grayscale images; labeled over 10 categories
(x_train2,y_train2),(x_test2,y_test2)=mnist.load_data()
n=int(len(x_test2)/2)
x_valid2,y_valid2=x_test2[:n],y_test2[:n]
x_test2,y_test2=x_test2[n:],y_test2[n:]
c_y_train2=keras.utils.to_categorical(y_train2,10)
c_y_valid2=keras.utils.to_categorical(y_valid2,10)
c_y_test2=keras.utils.to_categorical(y_test2,10)
x_train2.shape,x_valid2.shape,x_test2.shape
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 2s 0us/step
# ((60000, 28, 28), (5000, 28, 28), (5000, 28, 28))

# %%
fig,ax=pylab.subplots(figsize=(12,2),nrows=1,
                      ncols=5,sharex=True,sharey=True)
ax=ax.flatten()
for i in range(5):
    image=x_train2[i].reshape(28,28)
    ax[i].imshow(image,cmap=pylab.cm.bone)
ax[0].set_xticks([]); ax[0].set_yticks([])
pylab.tight_layout(); pylab.gcf()
ax[2].set_title('Examples of the 784-dimensional digits',
                fontsize=25);

# %%
t0=time.time()
X_emb=manifold.TSNE(n_components=2,learning_rate=700.0)\
              .fit_transform(x_test2.reshape(-1,784))
x_min,x_max=numpy.min(X_emb,0),numpy.max(X_emb,0)
X_emb=(X_emb-x_min)/(x_max-x_min)
f,ax=pylab.subplots(1,figsize=(12,5))
pylab.axis("off")
for i in range(X_emb.shape[0]):
    pylab.text(X_emb[i,0],X_emb[i,1],str(y_test2[i]),
               color=pylab.cm.hsv(y_test2[i]/10.))
pylab.title("t-SNE embedding %f s"%(time.time()-t0))
pylab.show()

# %% [markdown]
# # Classification 1

# %%
clf=[LogisticRegressionCV(solver='liblinear',
                          multi_class='ovr'),
     svm.SVC(gamma='scale',C=10.0,kernel='poly'),
     KNeighborsClassifier(),
     RadiusNeighborsClassifier(radius=30),
     RandomForestClassifier(n_estimators=64,
                            max_depth=11)]

# %%
 result=[]
 for c in clf:
   result.append(clf_fit_score(c,x_train1,x_test1,
                               y_train1,y_test1))

# %%
for i in range(5):
    print(result[i][0])
    print('accuracy train/test: %s'%result[i][3:5])
    print('loss train/test: %s'%result[i][5:7])
    print(80*'=')
# Out:
# LogisticRegressionCV(Cs=10, class_weight=None, cv=None, dual=False,
#                      fit_intercept=True, intercept_scaling=1.0, l1_ratios=None,
#                      max_iter=100, multi_class='ovr', n_jobs=None, penalty='l2',
#                      random_state=None, refit=True, scoring=None,
#                      solver='liblinear', tol=0.0001, verbose=0)
# accuracy train/test: [0.98469, 0.972222]
# loss train/test: [0.01531, 0.027778]
# ================================================================================
# SVC(C=10.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='poly',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
# accuracy train/test: [1.0, 0.986111]
# loss train/test: [0.0, 0.013889]
# ================================================================================
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')
# accuracy train/test: [0.98817, 0.994444]
# loss train/test: [0.01183, 0.005556]
# ================================================================================
# RadiusNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                           metric_params=None, n_jobs=None, outlier_label=None,
#                           p=2, radius=30, weights='uniform')
# accuracy train/test: [0.97634, 0.994444]
# loss train/test: [0.02366, 0.005556]
# ================================================================================
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=11, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=64,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# accuracy train/test: [1.0, 0.980556]
# loss train/test: [0.0, 0.019444]
# ================================================================================

# %%
pylab.figure(figsize=(12,5)); n=100; x=range(n)
pylab.scatter(x,y_test1[:n],marker='*',s=600,
              color='royalblue',label='Real data')
pylab.scatter(x,result[1][2][:n],marker='v',s=200,
              color='darkblue',label='SVC')
pylab.scatter(x,result[0][2][:n],marker='s',s=100,
              color='darkgrey',label='Logistic RegressionCV')
pylab.scatter(x,result[2][2][:n],marker='o',s=50,
              color='darkgreen',label='KNeighborsClassifier')
pylab.xlabel('Observations'); pylab.ylabel('Targets')
pylab.title('Classifiers. Test Results. Digits 1')
pylab.legend(loc=2,fontsize=10); pylab.show()

# %%
nn_clf1=MLPClassifier(hidden_layer_sizes=(512,),max_iter=70,
                      solver='sgd',verbose=1,
                      random_state=1,learning_rate_init=.01)
nn_clf1.fit(x_train1,y_train1)
[nn_clf1.score(x_train1,y_train1),
 nn_clf1.score(x_test1,y_test1)]
# Out:
# Iteration 1, loss = 8.00530122
# Iteration 2, loss = 0.40345160
# Iteration 3, loss = 0.18567301
# Iteration 4, loss = 0.11457804
# Iteration 5, loss = 0.08503822
# Iteration 6, loss = 0.07348423
# Iteration 7, loss = 0.05662412
# Iteration 8, loss = 0.05273783
# Iteration 9, loss = 0.04391314
# Iteration 10, loss = 0.03620788
# Iteration 11, loss = 0.03801262
# Iteration 12, loss = 0.02911084
# Iteration 13, loss = 0.02615359
# Iteration 14, loss = 0.02538807
# Iteration 15, loss = 0.02224096
# Iteration 16, loss = 0.02030931
# Iteration 17, loss = 0.01865935
# Iteration 18, loss = 0.01775010
# Iteration 19, loss = 0.01648355
# Iteration 20, loss = 0.01585530
# Iteration 21, loss = 0.01461249
# Iteration 22, loss = 0.01422504
# Iteration 23, loss = 0.01337695
# Iteration 24, loss = 0.01259988
# Iteration 25, loss = 0.01190659
# Iteration 26, loss = 0.01152053
# Iteration 27, loss = 0.01214406
# Iteration 28, loss = 0.01080019
# Iteration 29, loss = 0.01008233
# Iteration 30, loss = 0.00954526
# Iteration 31, loss = 0.00908236
# Iteration 32, loss = 0.00876074
# Iteration 33, loss = 0.00836976
# Iteration 34, loss = 0.00829602
# Iteration 35, loss = 0.00870930
# Iteration 36, loss = 0.00780019
# Iteration 37, loss = 0.00749420
# Iteration 38, loss = 0.00726695
# Iteration 39, loss = 0.00691664
# Iteration 40, loss = 0.00672090
# Iteration 41, loss = 0.00653468
# Iteration 42, loss = 0.00635692
# Iteration 43, loss = 0.00620201
# Iteration 44, loss = 0.00595856
# Iteration 45, loss = 0.00597278
# Iteration 46, loss = 0.00573345
# Iteration 47, loss = 0.00562445
# Iteration 48, loss = 0.00564442
# Iteration 49, loss = 0.00543213
# Iteration 50, loss = 0.00524446
# Iteration 51, loss = 0.00509109
# Iteration 52, loss = 0.00495292
# Iteration 53, loss = 0.00494970
# Iteration 54, loss = 0.00474500
# Iteration 55, loss = 0.00462808
# Iteration 56, loss = 0.00458971
# Iteration 57, loss = 0.00443582
# Iteration 58, loss = 0.00434442
# Iteration 59, loss = 0.00424040
# Iteration 60, loss = 0.00417276
# Iteration 61, loss = 0.00411430
# Iteration 62, loss = 0.00400607
# Iteration 63, loss = 0.00436994
# Iteration 64, loss = 0.00390899
# Iteration 65, loss = 0.00380770
# Iteration 66, loss = 0.00375763
# Iteration 67, loss = 0.00376438
# Iteration 68, loss = 0.00370108
# Iteration 69, loss = 0.00358662
# Iteration 70, loss = 0.00350452
# [1.0, 0.9916666666666667]

# %%
print("MLPClassifier:\n%s\n"\
      %(classification_report(y_test1,
                              nn_clf1.predict(x_test1))))
# Out:
# MLPClassifier:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        43
#            1       1.00      0.97      0.99        35
#            2       1.00      1.00      1.00        36
#            3       1.00      1.00      1.00        41
#            4       1.00      1.00      1.00        38
#            5       0.97      1.00      0.98        30
#            6       0.97      1.00      0.99        37
#            7       1.00      0.97      0.99        37
#            8       1.00      1.00      1.00        29
#            9       0.97      0.97      0.97        34
#
#     accuracy                           0.99       360
#    macro avg       0.99      0.99      0.99       360
# weighted avg       0.99      0.99      0.99       360

# %%
x_train1_scaled=\
(x_train1-numpy.min(x_train1,0))/(numpy.max(x_train1,0)+0.0001)
x_test1_scaled=\
(x_test1-numpy.min(x_test1,0))/(numpy.max(x_test1,0)+0.0001)
logistic=LogisticRegression(solver='liblinear',multi_class='ovr',
                            max_iter=50,tol=0.0001,C=5000.0)
brbm=BernoulliRBM(random_state=0,verbose=False)
brbm.learning_rate,brbm.n_iter,brbm.n_components=0.05,50,64
nn_clf2=Pipeline(steps=[('brbm',brbm),('logistic',logistic)])
nn_clf2.fit(x_train1_scaled,y_train1)
# Out:
# Pipeline(memory=None,
#          steps=[('brbm',
#                  BernoulliRBM(batch_size=10, learning_rate=0.05,
#                               n_components=64, n_iter=50, random_state=0,
#                               verbose=False)),
#                 ('logistic',
#                  LogisticRegression(C=5000.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=50,
#                                     multi_class='ovr', n_jobs=None,
#                                     penalty='l2', random_state=None,
#                                     solver='liblinear', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %%
print("Logistic regression using BRBM features:\n%s\n"\
      %(classification_report(y_test1,
                              nn_clf2.predict(x_test1_scaled))))
# Out:
# Logistic regression using BRBM features:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        43
#            1       0.97      0.97      0.97        35
#            2       0.97      0.97      0.97        36
#            3       0.95      1.00      0.98        41
#            4       0.97      0.97      0.97        38
#            5       0.94      0.97      0.95        30
#            6       1.00      1.00      1.00        37
#            7       0.94      0.89      0.92        37
#            8       0.90      0.90      0.90        29
#            9       0.97      0.97      0.97        34
#
#     accuracy                           0.96       360
#    macro avg       0.96      0.96      0.96       360
# weighted avg       0.96      0.96      0.96       360

# %% [markdown]
# # Classification 2

# %%
n_total=42000; n_labeled=38000
X2=numpy.copy(x_train2.reshape(-1,784)[:n_total])
y2=numpy.copy(y_train2[:n_total]).astype('int64')
y2[n_labeled:]=-1
lp_model=label_propagation\
         .LabelSpreading(kernel='knn',n_neighbors=10,max_iter=20)
lp_model.fit(X2,y2)
predicted_labels=lp_model.transduction_[n_labeled:n_total]
true_labels=y_train2[n_labeled:n_total]

# %%
print("Label Spreading: %d labeled & %d unlabeled points (%d total)"%
      (n_labeled,n_total-n_labeled,n_total))
print(classification_report(true_labels,predicted_labels))
print("Confusion matrix")
print(confusion_matrix(true_labels,predicted_labels,
                       labels=lp_model.classes_))
predict_entropies=\
stats.distributions.entropy(lp_model.label_distributions_.T)
uncertainty_index=numpy.argsort(predict_entropies)[-10:]
# Out:
# Label Spreading: 38000 labeled & 4000 unlabeled points (42000 total)
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       425
#            1       0.95      1.00      0.97       474
#            2       0.99      0.94      0.97       403
#            3       0.97      0.95      0.96       366
#            4       0.98      0.97      0.98       393
#            5       0.96      0.95      0.95       366
#            6       0.98      0.99      0.99       412
#            7       0.95      0.97      0.96       409
#            8       0.98      0.92      0.95       369
#            9       0.94      0.98      0.96       383
#
#     accuracy                           0.97      4000
#    macro avg       0.97      0.97      0.97      4000
# weighted avg       0.97      0.97      0.97      4000
#
# Confusion matrix
# [[418   2   0   0   0   1   4   0   0   0]
#  [  0 472   0   0   0   0   0   2   0   0]
#  [  2   7 380   0   1   0   1   9   1   2]
#  [  1   3   0 348   0   5   0   5   2   2]
#  [  0   5   0   0 382   0   0   0   0   6]
#  [  3   0   0   5   0 348   2   1   3   4]
#  [  2   1   0   0   0   1 408   0   0   0]
#  [  1   3   1   0   2   0   0 397   0   5]
#  [  0   5   2   4   3   8   1   1 340   5]
#  [  0   0   0   2   2   1   0   3   0 375]]

# %%
fig=pylab.figure(figsize=(12,5))
for index,image_index in enumerate(uncertainty_index):
    image=x_train2[image_index]
    sub=fig.add_subplot(2,5,index+1)
    sub.imshow(image,cmap=pylab.cm.bone)
    pylab.xticks([]); pylab.yticks([])
    sub.set_title('predict: %i\ntrue: %i'%(
        lp_model.transduction_[image_index],
        y_train2[image_index]))

# %% [markdown]
# # Classification 3

# %%
clf=MLPClassifier(hidden_layer_sizes=(256,),
                  max_iter=7,solver='adam',
                  verbose=0,random_state=1,
                  learning_rate_init=.001)
clf.fit(x_train2.reshape(-1,784),y_train2)
print(clf.score(x_test2.reshape(-1,784),y_test2),
      clf.score(x_valid2.reshape(-1,784),y_valid2))
y_test2_predictions=clf.predict(x_test2.reshape(-1,784))
pylab.figure(figsize=(12,5))
pylab.scatter(range(100),y_test2[:100],s=100)
pylab.scatter(range(100),y_test2_predictions[:100],s=25)
pylab.show()
# Out:
# 0.9722 0.9472

# %%
clf=MLPClassifier(hidden_layer_sizes=(196,),max_iter=100,alpha=1e-4,
                  solver='sgd',verbose=2, tol=1e-4,random_state=1,
                  learning_rate_init=1e-3)
clf.fit(x_train2.reshape(-1,784),y_train2)
print(clf.score(x_test2.reshape(-1,784),y_test2),
      clf.score(x_valid2.reshape(-1,784),y_valid2))
y_test2_predictions=clf.predict(x_test2.reshape(-1,784))
pylab.figure(figsize=(12,5))
pylab.scatter(range(100),y_test2[:100],s=100)
pylab.scatter(range(100),y_test2_predictions[:100],s=25)
pylab.show()
# Out:
# Iteration 1, loss = inf
# Iteration 2, loss = 0.48803416
# Iteration 3, loss = 0.35833288
# Iteration 4, loss = 0.31011372
# Iteration 5, loss = 0.27420066
# Iteration 6, loss = 0.25291703
# Iteration 7, loss = 0.23781368
# Iteration 8, loss = 0.22424604
# Iteration 9, loss = 0.21398827
# Iteration 10, loss = 0.20528451
# Iteration 11, loss = 0.19849473
# Iteration 12, loss = 0.19367508
# Iteration 13, loss = 0.18650326
# Iteration 14, loss = 0.17980426
# Iteration 15, loss = 0.17376308
# Iteration 16, loss = 0.17071259
# Iteration 17, loss = 0.16507464
# Iteration 18, loss = 0.16209422
# Iteration 19, loss = 0.15845685
# Iteration 20, loss = 0.15771982
# Iteration 21, loss = 0.15238208
# Iteration 22, loss = 0.14897335
# Iteration 23, loss = 0.14504865
# Iteration 24, loss = 0.14445808
# Iteration 25, loss = 0.14088064
# Iteration 26, loss = 0.13664035
# Iteration 27, loss = 0.13755860
# Iteration 28, loss = 0.13516427
# Iteration 29, loss = 0.13197702
# Iteration 30, loss = 0.13286604
# Iteration 31, loss = 0.13176581
# Iteration 32, loss = 0.12942058
# Iteration 33, loss = 0.12674796
# Iteration 34, loss = 0.12616541
# Iteration 35, loss = 0.12531739
# Iteration 36, loss = 0.12323820
# Iteration 37, loss = 0.12271833
# Iteration 38, loss = 0.11984780
# Iteration 39, loss = 0.11851749
# Iteration 40, loss = 0.11574603
# Iteration 41, loss = 0.11844408
# Iteration 42, loss = 0.11399833
# Iteration 43, loss = 0.11315271
# Iteration 44, loss = 0.11315154
# Iteration 45, loss = 0.11081324
# Iteration 46, loss = 0.10970804
# Iteration 47, loss = 0.10904672
# Iteration 48, loss = 0.10791781
# Iteration 49, loss = 0.10806207
# Iteration 50, loss = 0.10731782
# Iteration 51, loss = 0.10605707
# Iteration 52, loss = 0.10402411
# Iteration 53, loss = 0.10502192
# Iteration 54, loss = 0.10209173
# Iteration 55, loss = 0.10141416
# Iteration 56, loss = 0.10167248
# Iteration 57, loss = 0.09999733
# Iteration 58, loss = 0.09977923
# Iteration 59, loss = 0.09743238
# Iteration 60, loss = 0.09648377
# Iteration 61, loss = 0.09430731
# Iteration 62, loss = 0.09674958
# Iteration 63, loss = 0.09306125
# Iteration 64, loss = 0.09430910
# Iteration 65, loss = 0.09248384
# Iteration 66, loss = 0.09244373
# Iteration 67, loss = 0.09421213
# Iteration 68, loss = 0.09080974
# Iteration 69, loss = 0.08840281
# Iteration 70, loss = 0.09030620
# Iteration 71, loss = 0.08996797
# Iteration 72, loss = 0.08725941
# Iteration 73, loss = 0.08657452
# Iteration 74, loss = 0.08699409
# Iteration 75, loss = 0.08774568
# Iteration 76, loss = 0.08616907
# Iteration 77, loss = 0.08427612
# Iteration 78, loss = 0.08433377
# Iteration 79, loss = 0.08445397
# Iteration 80, loss = 0.08272540
# Iteration 81, loss = 0.08309876
# Iteration 82, loss = 0.08465617
# Iteration 83, loss = 0.08019564
# Iteration 84, loss = 0.08155072
# Iteration 85, loss = 0.08068883
# Iteration 86, loss = 0.08048466
# Iteration 87, loss = 0.08064856
# Iteration 88, loss = 0.07891863
# Iteration 89, loss = 0.07730235
# Iteration 90, loss = 0.07809729
# Iteration 91, loss = 0.07557366
# Iteration 92, loss = 0.07658039
# Iteration 93, loss = 0.07389132
# Iteration 94, loss = 0.07331183
# Iteration 95, loss = 0.07072745
# Iteration 96, loss = 0.07023666
# Iteration 97, loss = 0.07295072
# Iteration 98, loss = 0.07156915
# Iteration 99, loss = 0.07012273
# Iteration 100, loss = 0.07304519
# 0.9662 0.9274

# %%
def model():
    model=Sequential()    
    model.add(Dense(32,activation='relu',input_shape=(784,)))
    model.add(Dropout(rate=0.1))    
    model.add(Dense(1024,activation='relu'))
    model.add(Dropout(rate=0.1))    
    model.add(Dense(10,activation='softmax'))
    model.compile(optimizer='adam',loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model
model=model(); fw='weights.best.model.hdf5'
early_stopping=keras.callbacks.EarlyStopping(monitor='val_loss',patience=20)
checkpointer=keras.callbacks.ModelCheckpoint(filepath=fw,save_best_only=True)
lr_reduction=keras.callbacks.ReduceLROnPlateau(monitor='val_loss',verbose=2,
                                               patience=5,factor=0.5)
history=model.fit(x_train2.reshape(-1,784),c_y_train2, 
                  validation_data=(x_valid2.reshape(-1,784),c_y_valid2),
                  epochs=100,batch_size=128,verbose=0,
                  callbacks=[early_stopping,checkpointer,lr_reduction]);
# Out:
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.

# %%
history_plot(history)

# %%
model.load_weights(fw)
y_test2_predictions=model.predict_classes(x_test2.reshape(-1,784))
pylab.figure(figsize=(12,5))
pylab.scatter(range(100),y_test2[:100],s=100)
pylab.scatter(range(100),y_test2_predictions[:100],s=25)
model.evaluate(x_test2.reshape(-1,784),c_y_test2)
# Out:
# 5000/5000 [==============================] - 0s 47us/step
# [0.10616209608833306, 0.9765999913215637]

# %%
def model():
    model_input=Input(shape=(28,28,1))
    x=BatchNormalization()(model_input)   
#    x=Conv2D(28,(5,5),padding='same')(x)
#    x=LeakyReLU(alpha=0.02)(x)
#    x=MaxPooling2D(pool_size=(2, 2))(x)
#    x=Dropout(0.25)(x)   
    x=Conv2D(28,(5,5),padding='same')(x)
    x=LeakyReLU(alpha=0.02)(x)
    x=MaxPooling2D(strides=(2,2))(x)
    x=Dropout(0.25)(x)    
    x=Conv2D(128,(5,5))(x)
    x=LeakyReLU(alpha=0.02)(x)
    x=MaxPooling2D(strides=(2,2))(x)
    x=Dropout(0.25)(x) 
    x=GlobalMaxPooling2D()(x)  
    x=Dense(512)(x)
    x=LeakyReLU(alpha=0.02)(x)
    x=Dropout(0.5)(x)   
    y=Dense(10,activation='softmax')(x)   
    model=Model(input=model_input,output=y)    
#    optimizer=RMSprop(lr=0.001,rho=0.9,epsilon=1e-08,decay=0.0)   
    model.compile(loss='categorical_crossentropy',
                  optimizer='nadam',metrics=['accuracy'])
    return model
model=model(); fw='weights.best.model.hdf5'
early_stopping=keras.callbacks.EarlyStopping(monitor='val_loss',
                                             verbose=2,patience=20)
checkpointer=keras.callbacks.ModelCheckpoint(filepath=fw,verbose=2,
                                             save_best_only=True)
lr_reduction=keras.callbacks.ReduceLROnPlateau(monitor='val_loss',verbose=2,
                                               patience=5,factor=.75,
                                               min_lr=.000001)
history=model.fit(x_train2.reshape(-1,28,28,1),c_y_train2, 
                  validation_data=(x_valid2.reshape(-1,28,28,1),c_y_valid2),
                  epochs=100,batch_size=128,verbose=2,
                  callbacks=[early_stopping,checkpointer,lr_reduction]);
# Out:
# Train on 60000 samples, validate on 5000 samples
# Epoch 1/100
#  - 12s - loss: 0.2797 - accuracy: 0.9093 - val_loss: 0.0783 - val_accuracy: 0.9752
#
# Epoch 00001: val_loss improved from inf to 0.07832, saving model to weights.best.model.hdf5
# Epoch 2/100
#  - 5s - loss: 0.0758 - accuracy: 0.9769 - val_loss: 0.0536 - val_accuracy: 0.9824
#
# Epoch 00002: val_loss improved from 0.07832 to 0.05359, saving model to weights.best.model.hdf5
# Epoch 3/100
#  - 5s - loss: 0.0589 - accuracy: 0.9818 - val_loss: 0.0424 - val_accuracy: 0.9860
#
# Epoch 00003: val_loss improved from 0.05359 to 0.04240, saving model to weights.best.model.hdf5
# Epoch 4/100
#  - 5s - loss: 0.0503 - accuracy: 0.9842 - val_loss: 0.0420 - val_accuracy: 0.9852
#
# Epoch 00004: val_loss improved from 0.04240 to 0.04204, saving model to weights.best.model.hdf5
# Epoch 5/100
#  - 5s - loss: 0.0471 - accuracy: 0.9860 - val_loss: 0.0411 - val_accuracy: 0.9860
#
# Epoch 00005: val_loss improved from 0.04204 to 0.04115, saving model to weights.best.model.hdf5
# Epoch 6/100
#  - 5s - loss: 0.0447 - accuracy: 0.9858 - val_loss: 0.0365 - val_accuracy: 0.9888
#
# Epoch 00006: val_loss improved from 0.04115 to 0.03650, saving model to weights.best.model.hdf5
# Epoch 7/100
#  - 5s - loss: 0.0398 - accuracy: 0.9877 - val_loss: 0.0375 - val_accuracy: 0.9860
#
# Epoch 00007: val_loss did not improve from 0.03650
# Epoch 8/100
#  - 5s - loss: 0.0364 - accuracy: 0.9890 - val_loss: 0.0310 - val_accuracy: 0.9892
#
# Epoch 00008: val_loss improved from 0.03650 to 0.03101, saving model to weights.best.model.hdf5
# Epoch 9/100
#  - 5s - loss: 0.0338 - accuracy: 0.9893 - val_loss: 0.0411 - val_accuracy: 0.9872
#
# Epoch 00009: val_loss did not improve from 0.03101
# Epoch 10/100
#  - 5s - loss: 0.0323 - accuracy: 0.9902 - val_loss: 0.0328 - val_accuracy: 0.9906
#
# Epoch 00010: val_loss did not improve from 0.03101
# Epoch 11/100
#  - 5s - loss: 0.0313 - accuracy: 0.9899 - val_loss: 0.0388 - val_accuracy: 0.9868
#
# Epoch 00011: val_loss did not improve from 0.03101
# Epoch 12/100
#  - 5s - loss: 0.0313 - accuracy: 0.9905 - val_loss: 0.0335 - val_accuracy: 0.9894
#
# Epoch 00012: val_loss did not improve from 0.03101
# Epoch 13/100
#  - 5s - loss: 0.0291 - accuracy: 0.9911 - val_loss: 0.0334 - val_accuracy: 0.9896
#
# Epoch 00013: val_loss did not improve from 0.03101
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.001500000071246177.
# Epoch 14/100
#  - 5s - loss: 0.0234 - accuracy: 0.9925 - val_loss: 0.0287 - val_accuracy: 0.9902
#
# Epoch 00014: val_loss improved from 0.03101 to 0.02872, saving model to weights.best.model.hdf5
# Epoch 15/100
#  - 5s - loss: 0.0229 - accuracy: 0.9925 - val_loss: 0.0275 - val_accuracy: 0.9918
#
# Epoch 00015: val_loss improved from 0.02872 to 0.02753, saving model to weights.best.model.hdf5
# Epoch 16/100
#  - 5s - loss: 0.0222 - accuracy: 0.9927 - val_loss: 0.0280 - val_accuracy: 0.9908
#
# Epoch 00016: val_loss did not improve from 0.02753
# Epoch 17/100
#  - 5s - loss: 0.0215 - accuracy: 0.9930 - val_loss: 0.0346 - val_accuracy: 0.9886
#
# Epoch 00017: val_loss did not improve from 0.02753
# Epoch 18/100
#  - 5s - loss: 0.0207 - accuracy: 0.9934 - val_loss: 0.0258 - val_accuracy: 0.9924
#
# Epoch 00018: val_loss improved from 0.02753 to 0.02585, saving model to weights.best.model.hdf5
# Epoch 19/100
#  - 5s - loss: 0.0199 - accuracy: 0.9939 - val_loss: 0.0293 - val_accuracy: 0.9908
#
# Epoch 00019: val_loss did not improve from 0.02585
# Epoch 20/100
#  - 5s - loss: 0.0194 - accuracy: 0.9938 - val_loss: 0.0257 - val_accuracy: 0.9920
#
# Epoch 00020: val_loss improved from 0.02585 to 0.02567, saving model to weights.best.model.hdf5
# Epoch 21/100
#  - 5s - loss: 0.0185 - accuracy: 0.9942 - val_loss: 0.0329 - val_accuracy: 0.9900
#
# Epoch 00021: val_loss did not improve from 0.02567
# Epoch 22/100
#  - 5s - loss: 0.0197 - accuracy: 0.9934 - val_loss: 0.0290 - val_accuracy: 0.9908
#
# Epoch 00022: val_loss did not improve from 0.02567
# Epoch 23/100
#  - 5s - loss: 0.0194 - accuracy: 0.9941 - val_loss: 0.0298 - val_accuracy: 0.9910
#
# Epoch 00023: val_loss did not improve from 0.02567
# Epoch 24/100
#  - 5s - loss: 0.0185 - accuracy: 0.9941 - val_loss: 0.0287 - val_accuracy: 0.9902
#
# Epoch 00024: val_loss did not improve from 0.02567
# Epoch 25/100
#  - 5s - loss: 0.0157 - accuracy: 0.9946 - val_loss: 0.0345 - val_accuracy: 0.9912
#
# Epoch 00025: val_loss did not improve from 0.02567
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.001125000009778887.
# Epoch 26/100
#  - 5s - loss: 0.0157 - accuracy: 0.9950 - val_loss: 0.0253 - val_accuracy: 0.9918
#
# Epoch 00026: val_loss improved from 0.02567 to 0.02526, saving model to weights.best.model.hdf5
# Epoch 27/100
#  - 5s - loss: 0.0132 - accuracy: 0.9956 - val_loss: 0.0261 - val_accuracy: 0.9916
#
# Epoch 00027: val_loss did not improve from 0.02526
# Epoch 28/100
#  - 5s - loss: 0.0139 - accuracy: 0.9954 - val_loss: 0.0270 - val_accuracy: 0.9912
#
# Epoch 00028: val_loss did not improve from 0.02526
# Epoch 29/100
#  - 5s - loss: 0.0141 - accuracy: 0.9955 - val_loss: 0.0248 - val_accuracy: 0.9922
#
# Epoch 00029: val_loss improved from 0.02526 to 0.02478, saving model to weights.best.model.hdf5
# Epoch 30/100
#  - 5s - loss: 0.0123 - accuracy: 0.9962 - val_loss: 0.0292 - val_accuracy: 0.9896
#
# Epoch 00030: val_loss did not improve from 0.02478
# Epoch 31/100
#  - 5s - loss: 0.0139 - accuracy: 0.9956 - val_loss: 0.0292 - val_accuracy: 0.9902
#
# Epoch 00031: val_loss did not improve from 0.02478
# Epoch 32/100
#  - 5s - loss: 0.0124 - accuracy: 0.9961 - val_loss: 0.0302 - val_accuracy: 0.9904
#
# Epoch 00032: val_loss did not improve from 0.02478
# Epoch 33/100
#  - 5s - loss: 0.0139 - accuracy: 0.9956 - val_loss: 0.0278 - val_accuracy: 0.9916
#
# Epoch 00033: val_loss did not improve from 0.02478
# Epoch 34/100
#  - 5s - loss: 0.0118 - accuracy: 0.9963 - val_loss: 0.0256 - val_accuracy: 0.9928
#
# Epoch 00034: val_loss did not improve from 0.02478
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0008437499636784196.
# Epoch 35/100
#  - 5s - loss: 0.0108 - accuracy: 0.9966 - val_loss: 0.0267 - val_accuracy: 0.9916
#
# Epoch 00035: val_loss did not improve from 0.02478
# Epoch 36/100
#  - 5s - loss: 0.0101 - accuracy: 0.9967 - val_loss: 0.0279 - val_accuracy: 0.9922
#
# Epoch 00036: val_loss did not improve from 0.02478
# Epoch 37/100
#  - 5s - loss: 0.0095 - accuracy: 0.9967 - val_loss: 0.0258 - val_accuracy: 0.9920
#
# Epoch 00037: val_loss did not improve from 0.02478
# Epoch 38/100
#  - 5s - loss: 0.0089 - accuracy: 0.9973 - val_loss: 0.0226 - val_accuracy: 0.9916
#
# Epoch 00038: val_loss improved from 0.02478 to 0.02258, saving model to weights.best.model.hdf5
# Epoch 39/100
#  - 5s - loss: 0.0105 - accuracy: 0.9965 - val_loss: 0.0265 - val_accuracy: 0.9926
#
# Epoch 00039: val_loss did not improve from 0.02258
# Epoch 40/100
#  - 5s - loss: 0.0100 - accuracy: 0.9968 - val_loss: 0.0294 - val_accuracy: 0.9918
#
# Epoch 00040: val_loss did not improve from 0.02258
# Epoch 41/100
#  - 5s - loss: 0.0088 - accuracy: 0.9968 - val_loss: 0.0260 - val_accuracy: 0.9924
#
# Epoch 00041: val_loss did not improve from 0.02258
# Epoch 42/100
#  - 5s - loss: 0.0095 - accuracy: 0.9969 - val_loss: 0.0250 - val_accuracy: 0.9924
#
# Epoch 00042: val_loss did not improve from 0.02258
# Epoch 43/100
#  - 5s - loss: 0.0091 - accuracy: 0.9970 - val_loss: 0.0331 - val_accuracy: 0.9906
#
# Epoch 00043: val_loss did not improve from 0.02258
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0006328124727588147.
# Epoch 44/100
#  - 5s - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.0273 - val_accuracy: 0.9924
#
# Epoch 00044: val_loss did not improve from 0.02258
# Epoch 45/100
#  - 5s - loss: 0.0078 - accuracy: 0.9976 - val_loss: 0.0256 - val_accuracy: 0.9928
#
# Epoch 00045: val_loss did not improve from 0.02258
# Epoch 46/100
#  - 5s - loss: 0.0069 - accuracy: 0.9975 - val_loss: 0.0271 - val_accuracy: 0.9914
#
# Epoch 00046: val_loss did not improve from 0.02258
# Epoch 47/100
#  - 5s - loss: 0.0072 - accuracy: 0.9978 - val_loss: 0.0233 - val_accuracy: 0.9920
#
# Epoch 00047: val_loss did not improve from 0.02258
# Epoch 48/100
#  - 5s - loss: 0.0064 - accuracy: 0.9979 - val_loss: 0.0260 - val_accuracy: 0.9926
#
# Epoch 00048: val_loss did not improve from 0.02258
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.00047460937639698386.
# Epoch 49/100
#  - 5s - loss: 0.0061 - accuracy: 0.9979 - val_loss: 0.0234 - val_accuracy: 0.9928
#
# Epoch 00049: val_loss did not improve from 0.02258
# Epoch 50/100
#  - 5s - loss: 0.0067 - accuracy: 0.9979 - val_loss: 0.0258 - val_accuracy: 0.9920
#
# Epoch 00050: val_loss did not improve from 0.02258
# Epoch 51/100
#  - 5s - loss: 0.0051 - accuracy: 0.9982 - val_loss: 0.0229 - val_accuracy: 0.9936
#
# Epoch 00051: val_loss did not improve from 0.02258
# Epoch 52/100
#  - 5s - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.0244 - val_accuracy: 0.9930
#
# Epoch 00052: val_loss did not improve from 0.02258
# Epoch 53/100
#  - 5s - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.0275 - val_accuracy: 0.9920
#
# Epoch 00053: val_loss did not improve from 0.02258
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 0.0003559570322977379.
# Epoch 54/100
#  - 5s - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.0262 - val_accuracy: 0.9922
#
# Epoch 00054: val_loss did not improve from 0.02258
# Epoch 55/100
#  - 5s - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.0258 - val_accuracy: 0.9930
#
# Epoch 00055: val_loss did not improve from 0.02258
# Epoch 56/100
#  - 5s - loss: 0.0040 - accuracy: 0.9986 - val_loss: 0.0249 - val_accuracy: 0.9926
#
# Epoch 00056: val_loss did not improve from 0.02258
# Epoch 57/100
#  - 5s - loss: 0.0045 - accuracy: 0.9985 - val_loss: 0.0228 - val_accuracy: 0.9940
#
# Epoch 00057: val_loss did not improve from 0.02258
# Epoch 58/100
#  - 5s - loss: 0.0044 - accuracy: 0.9985 - val_loss: 0.0235 - val_accuracy: 0.9918
#
# Epoch 00058: val_loss did not improve from 0.02258
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 0.000266967763309367.
# Epoch 00058: early stopping

# %%
history_plot(history)

# %%
model.load_weights(fw)
y_test2_predictions=\
model.predict(x_test2.reshape(-1,28,28,1))\
.argmax(axis=-1)
pylab.figure(figsize=(12,5))
pylab.scatter(range(100),y_test2[:100],s=100)
pylab.scatter(range(100),y_test2_predictions[:100],s=25)
model.evaluate(x_test2.reshape(-1,28,28,1),c_y_test2)
# Out:
# 5000/5000 [==============================] - 0s 76us/step
# [0.00814694658572057, 0.996999979019165]

# %%
steps,epochs=1000,50
data_generator=\
ImageDataGenerator(zoom_range=0.2,shear_range=0.2, 
                   rotation_range=20,width_shift_range=0.2,
                   height_shift_range=0.2)
data_generator.fit(x_train2.reshape(-1,28,28,1))

# %%
history=model.\
fit_generator(data_generator.flow(x_train2.reshape(-1,28,28,1),
                                  c_y_train2,batch_size=128),
              steps_per_epoch=steps,epochs=epochs,verbose=2,
              validation_data=(x_valid2.reshape(-1,28,28,1),c_y_valid2), 
              callbacks=[early_stopping,checkpointer,lr_reduction])
# Out:
# Epoch 1/50
#  - 31s - loss: 0.1247 - accuracy: 0.9622 - val_loss: 0.0244 - val_accuracy: 0.9926
#
# Epoch 00001: val_loss did not improve from 0.02258
# Epoch 2/50
#  - 31s - loss: 0.0946 - accuracy: 0.9714 - val_loss: 0.0217 - val_accuracy: 0.9932
#
# Epoch 00002: val_loss improved from 0.02258 to 0.02166, saving model to weights.best.model.hdf5
# Epoch 3/50
#  - 31s - loss: 0.0827 - accuracy: 0.9749 - val_loss: 0.0227 - val_accuracy: 0.9928
#
# Epoch 00003: val_loss did not improve from 0.02166
# Epoch 4/50
#  - 31s - loss: 0.0771 - accuracy: 0.9768 - val_loss: 0.0209 - val_accuracy: 0.9938
#
# Epoch 00004: val_loss improved from 0.02166 to 0.02092, saving model to weights.best.model.hdf5
# Epoch 5/50
#  - 31s - loss: 0.0741 - accuracy: 0.9775 - val_loss: 0.0210 - val_accuracy: 0.9936
#
# Epoch 00005: val_loss did not improve from 0.02092
# Epoch 6/50
#  - 30s - loss: 0.0718 - accuracy: 0.9781 - val_loss: 0.0206 - val_accuracy: 0.9938
#
# Epoch 00006: val_loss improved from 0.02092 to 0.02063, saving model to weights.best.model.hdf5
# Epoch 7/50
#  - 31s - loss: 0.0665 - accuracy: 0.9798 - val_loss: 0.0205 - val_accuracy: 0.9936
#
# Epoch 00007: val_loss improved from 0.02063 to 0.02046, saving model to weights.best.model.hdf5
# Epoch 8/50
#  - 31s - loss: 0.0649 - accuracy: 0.9804 - val_loss: 0.0198 - val_accuracy: 0.9938
#
# Epoch 00008: val_loss improved from 0.02046 to 0.01980, saving model to weights.best.model.hdf5
# Epoch 9/50
#  - 31s - loss: 0.0610 - accuracy: 0.9814 - val_loss: 0.0192 - val_accuracy: 0.9938
#
# Epoch 00009: val_loss improved from 0.01980 to 0.01915, saving model to weights.best.model.hdf5
# Epoch 10/50
#  - 31s - loss: 0.0620 - accuracy: 0.9815 - val_loss: 0.0193 - val_accuracy: 0.9940
#
# Epoch 00010: val_loss did not improve from 0.01915
# Epoch 11/50
#  - 31s - loss: 0.0603 - accuracy: 0.9817 - val_loss: 0.0198 - val_accuracy: 0.9936
#
# Epoch 00011: val_loss did not improve from 0.01915
# Epoch 12/50
#  - 30s - loss: 0.0582 - accuracy: 0.9822 - val_loss: 0.0198 - val_accuracy: 0.9944
#
# Epoch 00012: val_loss did not improve from 0.01915
# Epoch 13/50
#  - 30s - loss: 0.0563 - accuracy: 0.9829 - val_loss: 0.0184 - val_accuracy: 0.9946
#
# Epoch 00013: val_loss improved from 0.01915 to 0.01840, saving model to weights.best.model.hdf5
# Epoch 14/50
#  - 30s - loss: 0.0554 - accuracy: 0.9831 - val_loss: 0.0199 - val_accuracy: 0.9938
#
# Epoch 00014: val_loss did not improve from 0.01840
# Epoch 15/50
#  - 30s - loss: 0.0539 - accuracy: 0.9836 - val_loss: 0.0180 - val_accuracy: 0.9944
#
# Epoch 00015: val_loss improved from 0.01840 to 0.01802, saving model to weights.best.model.hdf5
# Epoch 16/50
#  - 30s - loss: 0.0542 - accuracy: 0.9831 - val_loss: 0.0186 - val_accuracy: 0.9938
#
# Epoch 00016: val_loss did not improve from 0.01802
# Epoch 17/50
#  - 30s - loss: 0.0523 - accuracy: 0.9837 - val_loss: 0.0186 - val_accuracy: 0.9936
#
# Epoch 00017: val_loss did not improve from 0.01802
# Epoch 18/50
#  - 30s - loss: 0.0511 - accuracy: 0.9844 - val_loss: 0.0197 - val_accuracy: 0.9938
#
# Epoch 00018: val_loss did not improve from 0.01802
# Epoch 19/50
#  - 30s - loss: 0.0502 - accuracy: 0.9845 - val_loss: 0.0175 - val_accuracy: 0.9936
#
# Epoch 00019: val_loss improved from 0.01802 to 0.01752, saving model to weights.best.model.hdf5
# Epoch 20/50
#  - 30s - loss: 0.0516 - accuracy: 0.9842 - val_loss: 0.0192 - val_accuracy: 0.9934
#
# Epoch 00020: val_loss did not improve from 0.01752
# Epoch 21/50
#  - 30s - loss: 0.0490 - accuracy: 0.9849 - val_loss: 0.0188 - val_accuracy: 0.9940
#
# Epoch 00021: val_loss did not improve from 0.01752
# Epoch 22/50
#  - 30s - loss: 0.0479 - accuracy: 0.9853 - val_loss: 0.0178 - val_accuracy: 0.9944
#
# Epoch 00022: val_loss did not improve from 0.01752
# Epoch 23/50
#  - 30s - loss: 0.0452 - accuracy: 0.9860 - val_loss: 0.0185 - val_accuracy: 0.9936
#
# Epoch 00023: val_loss did not improve from 0.01752
# Epoch 24/50
#  - 30s - loss: 0.0477 - accuracy: 0.9853 - val_loss: 0.0182 - val_accuracy: 0.9938
#
# Epoch 00024: val_loss did not improve from 0.01752
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.00020022581156808883.
# Epoch 25/50
#  - 30s - loss: 0.0466 - accuracy: 0.9860 - val_loss: 0.0183 - val_accuracy: 0.9940
#
# Epoch 00025: val_loss did not improve from 0.01752
# Epoch 26/50
#  - 30s - loss: 0.0455 - accuracy: 0.9864 - val_loss: 0.0175 - val_accuracy: 0.9942
#
# Epoch 00026: val_loss improved from 0.01752 to 0.01747, saving model to weights.best.model.hdf5
# Epoch 27/50
#  - 30s - loss: 0.0433 - accuracy: 0.9867 - val_loss: 0.0181 - val_accuracy: 0.9942
#
# Epoch 00027: val_loss did not improve from 0.01747
# Epoch 28/50
#  - 30s - loss: 0.0439 - accuracy: 0.9868 - val_loss: 0.0184 - val_accuracy: 0.9936
#
# Epoch 00028: val_loss did not improve from 0.01747
# Epoch 29/50
#  - 30s - loss: 0.0429 - accuracy: 0.9868 - val_loss: 0.0175 - val_accuracy: 0.9948
#
# Epoch 00029: val_loss did not improve from 0.01747
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.00015016935867606662.
# Epoch 30/50
#  - 30s - loss: 0.0421 - accuracy: 0.9869 - val_loss: 0.0177 - val_accuracy: 0.9942
#
# Epoch 00030: val_loss did not improve from 0.01747
# Epoch 31/50
#  - 30s - loss: 0.0405 - accuracy: 0.9876 - val_loss: 0.0164 - val_accuracy: 0.9944
#
# Epoch 00031: val_loss improved from 0.01747 to 0.01645, saving model to weights.best.model.hdf5
# Epoch 32/50
#  - 30s - loss: 0.0408 - accuracy: 0.9872 - val_loss: 0.0176 - val_accuracy: 0.9942
#
# Epoch 00032: val_loss did not improve from 0.01645
# Epoch 33/50
#  - 30s - loss: 0.0431 - accuracy: 0.9871 - val_loss: 0.0164 - val_accuracy: 0.9944
#
# Epoch 00033: val_loss improved from 0.01645 to 0.01641, saving model to weights.best.model.hdf5
# Epoch 34/50
#  - 30s - loss: 0.0411 - accuracy: 0.9873 - val_loss: 0.0170 - val_accuracy: 0.9942
#
# Epoch 00034: val_loss did not improve from 0.01641
# Epoch 35/50
#  - 30s - loss: 0.0400 - accuracy: 0.9875 - val_loss: 0.0163 - val_accuracy: 0.9948
#
# Epoch 00035: val_loss improved from 0.01641 to 0.01634, saving model to weights.best.model.hdf5
# Epoch 36/50
#  - 30s - loss: 0.0410 - accuracy: 0.9874 - val_loss: 0.0165 - val_accuracy: 0.9946
#
# Epoch 00036: val_loss did not improve from 0.01634
# Epoch 37/50
#  - 30s - loss: 0.0390 - accuracy: 0.9877 - val_loss: 0.0174 - val_accuracy: 0.9942
#
# Epoch 00037: val_loss did not improve from 0.01634
# Epoch 38/50
#  - 30s - loss: 0.0400 - accuracy: 0.9877 - val_loss: 0.0167 - val_accuracy: 0.9948
#
# Epoch 00038: val_loss did not improve from 0.01634
# Epoch 39/50
#  - 30s - loss: 0.0411 - accuracy: 0.9876 - val_loss: 0.0162 - val_accuracy: 0.9942
#
# Epoch 00039: val_loss improved from 0.01634 to 0.01624, saving model to weights.best.model.hdf5
# Epoch 40/50
#  - 31s - loss: 0.0406 - accuracy: 0.9876 - val_loss: 0.0173 - val_accuracy: 0.9946
#
# Epoch 00040: val_loss did not improve from 0.01624
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.00011262702173553407.
# Epoch 41/50
#  - 30s - loss: 0.0392 - accuracy: 0.9877 - val_loss: 0.0164 - val_accuracy: 0.9944
#
# Epoch 00041: val_loss did not improve from 0.01624
# Epoch 42/50
#  - 30s - loss: 0.0394 - accuracy: 0.9878 - val_loss: 0.0167 - val_accuracy: 0.9940
#
# Epoch 00042: val_loss did not improve from 0.01624
# Epoch 43/50
#  - 30s - loss: 0.0396 - accuracy: 0.9881 - val_loss: 0.0159 - val_accuracy: 0.9944
#
# Epoch 00043: val_loss improved from 0.01624 to 0.01587, saving model to weights.best.model.hdf5
# Epoch 44/50
#  - 30s - loss: 0.0393 - accuracy: 0.9882 - val_loss: 0.0169 - val_accuracy: 0.9946
#
# Epoch 00044: val_loss did not improve from 0.01587
# Epoch 45/50
#  - 30s - loss: 0.0394 - accuracy: 0.9880 - val_loss: 0.0164 - val_accuracy: 0.9942
#
# Epoch 00045: val_loss did not improve from 0.01587
# Epoch 46/50
#  - 30s - loss: 0.0390 - accuracy: 0.9880 - val_loss: 0.0167 - val_accuracy: 0.9942
#
# Epoch 00046: val_loss did not improve from 0.01587
# Epoch 47/50
#  - 30s - loss: 0.0372 - accuracy: 0.9885 - val_loss: 0.0171 - val_accuracy: 0.9942
#
# Epoch 00047: val_loss did not improve from 0.01587
# Epoch 48/50
#  - 30s - loss: 0.0397 - accuracy: 0.9876 - val_loss: 0.0170 - val_accuracy: 0.9946
#
# Epoch 00048: val_loss did not improve from 0.01587
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 8.447026630165055e-05.
# Epoch 49/50
#  - 30s - loss: 0.0374 - accuracy: 0.9885 - val_loss: 0.0160 - val_accuracy: 0.9946
#
# Epoch 00049: val_loss did not improve from 0.01587
# Epoch 50/50
#  - 31s - loss: 0.0367 - accuracy: 0.9887 - val_loss: 0.0164 - val_accuracy: 0.9946
#
# Epoch 00050: val_loss did not improve from 0.01587

# %%
history_plot(history)

# %%
model.load_weights(fw)
y_test2_predictions=\
model.predict(x_test2.reshape(-1,28,28,1))\
.argmax(axis=-1)
pylab.figure(figsize=(12,5))
pylab.scatter(range(100),y_test2[:100],s=100)
pylab.scatter(range(100),y_test2_predictions[:100],s=25)
model.evaluate(x_test2.reshape(-1,28,28,1),c_y_test2)
# Out:
# 5000/5000 [==============================] - 0s 77us/step
# [0.010128641149029135, 0.9968000054359436]

# %%
def model():
    model=Sequential()
    model.add(LSTM(196,return_sequences=True,
                   input_shape=(1,784)))    
    model.add(LSTM(196,return_sequences=True))   
    model.add(LSTM(784))      
    model.add(Dense(10, activation='softmax'))
    model.compile(loss='categorical_crossentropy', 
                  optimizer='nadam', metrics=['accuracy'])    
    return model
model=model(); fw='weights.best.model.hdf5'
early_stopping=keras.callbacks.EarlyStopping(monitor='val_loss',patience=20)
checkpointer=keras.callbacks.ModelCheckpoint(filepath=fw,save_best_only=True)
lr_reduction=keras.callbacks.ReduceLROnPlateau(monitor='val_loss',verbose=2,
                                               patience=5,factor=.75,
                                               min_lr=.000001)
history=model.fit(x_train2.reshape(-1,1,784),c_y_train2, 
                  validation_data=(x_valid2.reshape(-1,1,784),c_y_valid2),
                  epochs=100,batch_size=128,verbose=2,
                  callbacks=[early_stopping,checkpointer,lr_reduction]);
# Out:
# Train on 60000 samples, validate on 5000 samples
# Epoch 1/100
#  - 7s - loss: 0.4994 - accuracy: 0.8373 - val_loss: 0.4467 - val_accuracy: 0.8468
# Epoch 2/100
#  - 6s - loss: 0.3729 - accuracy: 0.8801 - val_loss: 0.3967 - val_accuracy: 0.8754
# Epoch 3/100
#  - 6s - loss: 0.3158 - accuracy: 0.8979 - val_loss: 0.3682 - val_accuracy: 0.8818
# Epoch 4/100
#  - 6s - loss: 0.2574 - accuracy: 0.9167 - val_loss: 0.3033 - val_accuracy: 0.9040
# Epoch 5/100
#  - 6s - loss: 0.2580 - accuracy: 0.9157 - val_loss: 0.3244 - val_accuracy: 0.8968
# Epoch 6/100
#  - 6s - loss: 0.2286 - accuracy: 0.9260 - val_loss: 0.2939 - val_accuracy: 0.9050
# Epoch 7/100
#  - 6s - loss: 0.2243 - accuracy: 0.9269 - val_loss: 0.2702 - val_accuracy: 0.9148
# Epoch 8/100
#  - 6s - loss: 0.2101 - accuracy: 0.9315 - val_loss: 0.2625 - val_accuracy: 0.9178
# Epoch 9/100
#  - 6s - loss: 0.2037 - accuracy: 0.9324 - val_loss: 0.2539 - val_accuracy: 0.9184
# Epoch 10/100
#  - 6s - loss: 0.1945 - accuracy: 0.9348 - val_loss: 0.2768 - val_accuracy: 0.9120
# Epoch 11/100
#  - 6s - loss: 0.1921 - accuracy: 0.9369 - val_loss: 0.2514 - val_accuracy: 0.9228
# Epoch 12/100
#  - 6s - loss: 0.1811 - accuracy: 0.9409 - val_loss: 0.2523 - val_accuracy: 0.9156
# Epoch 13/100
#  - 6s - loss: 0.1802 - accuracy: 0.9402 - val_loss: 0.2481 - val_accuracy: 0.9196
# Epoch 14/100
#  - 6s - loss: 0.1673 - accuracy: 0.9447 - val_loss: 0.2173 - val_accuracy: 0.9308
# Epoch 15/100
#  - 6s - loss: 0.1609 - accuracy: 0.9466 - val_loss: 0.2021 - val_accuracy: 0.9352
# Epoch 16/100
#  - 6s - loss: 0.1544 - accuracy: 0.9493 - val_loss: 0.2257 - val_accuracy: 0.9246
# Epoch 17/100
#  - 6s - loss: 0.1560 - accuracy: 0.9479 - val_loss: 0.2291 - val_accuracy: 0.9292
# Epoch 18/100
#  - 6s - loss: 0.1506 - accuracy: 0.9497 - val_loss: 0.2161 - val_accuracy: 0.9288
# Epoch 19/100
#  - 6s - loss: 0.1596 - accuracy: 0.9467 - val_loss: 0.2317 - val_accuracy: 0.9272
# Epoch 20/100
#  - 6s - loss: 0.1382 - accuracy: 0.9545 - val_loss: 0.1844 - val_accuracy: 0.9390
# Epoch 21/100
#  - 6s - loss: 0.1309 - accuracy: 0.9560 - val_loss: 0.2013 - val_accuracy: 0.9352
# Epoch 22/100
#  - 6s - loss: 0.1340 - accuracy: 0.9557 - val_loss: 0.1914 - val_accuracy: 0.9368
# Epoch 23/100
#  - 6s - loss: 0.1392 - accuracy: 0.9530 - val_loss: 0.1911 - val_accuracy: 0.9410
# Epoch 24/100
#  - 6s - loss: 0.1356 - accuracy: 0.9547 - val_loss: 0.2083 - val_accuracy: 0.9326
# Epoch 25/100
#  - 6s - loss: 0.1215 - accuracy: 0.9596 - val_loss: 0.1985 - val_accuracy: 0.9392
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.001500000071246177.
# Epoch 26/100
#  - 6s - loss: 0.1127 - accuracy: 0.9625 - val_loss: 0.1837 - val_accuracy: 0.9420
# Epoch 27/100
#  - 6s - loss: 0.1123 - accuracy: 0.9630 - val_loss: 0.1765 - val_accuracy: 0.9422
# Epoch 28/100
#  - 6s - loss: 0.1033 - accuracy: 0.9657 - val_loss: 0.1707 - val_accuracy: 0.9466
# Epoch 29/100
#  - 6s - loss: 0.1020 - accuracy: 0.9648 - val_loss: 0.1678 - val_accuracy: 0.9454
# Epoch 30/100
#  - 6s - loss: 0.0964 - accuracy: 0.9675 - val_loss: 0.1707 - val_accuracy: 0.9456
# Epoch 31/100
#  - 6s - loss: 0.0969 - accuracy: 0.9670 - val_loss: 0.1927 - val_accuracy: 0.9392
# Epoch 32/100
#  - 6s - loss: 0.1004 - accuracy: 0.9656 - val_loss: 0.1880 - val_accuracy: 0.9404
# Epoch 33/100
#  - 6s - loss: 0.1015 - accuracy: 0.9657 - val_loss: 0.1836 - val_accuracy: 0.9422
# Epoch 34/100
#  - 6s - loss: 0.0974 - accuracy: 0.9678 - val_loss: 0.1610 - val_accuracy: 0.9504
# Epoch 35/100
#  - 6s - loss: 0.0924 - accuracy: 0.9686 - val_loss: 0.1702 - val_accuracy: 0.9466
# Epoch 36/100
#  - 6s - loss: 0.0917 - accuracy: 0.9690 - val_loss: 0.1714 - val_accuracy: 0.9456
# Epoch 37/100
#  - 6s - loss: 0.0910 - accuracy: 0.9687 - val_loss: 0.1777 - val_accuracy: 0.9448
# Epoch 38/100
#  - 6s - loss: 0.0942 - accuracy: 0.9676 - val_loss: 0.1783 - val_accuracy: 0.9476
# Epoch 39/100
#  - 6s - loss: 0.0944 - accuracy: 0.9675 - val_loss: 0.1772 - val_accuracy: 0.9454
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.001125000009778887.
# Epoch 40/100
#  - 6s - loss: 0.0802 - accuracy: 0.9728 - val_loss: 0.1678 - val_accuracy: 0.9496
# Epoch 41/100
#  - 6s - loss: 0.0733 - accuracy: 0.9745 - val_loss: 0.1591 - val_accuracy: 0.9536
# Epoch 42/100
#  - 6s - loss: 0.0719 - accuracy: 0.9753 - val_loss: 0.1709 - val_accuracy: 0.9484
# Epoch 43/100
#  - 6s - loss: 0.0683 - accuracy: 0.9761 - val_loss: 0.1613 - val_accuracy: 0.9528
# Epoch 44/100
#  - 6s - loss: 0.0659 - accuracy: 0.9772 - val_loss: 0.1674 - val_accuracy: 0.9472
# Epoch 45/100
#  - 6s - loss: 0.0638 - accuracy: 0.9779 - val_loss: 0.1715 - val_accuracy: 0.9508
# Epoch 46/100
#  - 6s - loss: 0.0681 - accuracy: 0.9760 - val_loss: 0.1676 - val_accuracy: 0.9532
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.0008437499636784196.
# Epoch 47/100
#  - 6s - loss: 0.0553 - accuracy: 0.9807 - val_loss: 0.1648 - val_accuracy: 0.9548
# Epoch 48/100
#  - 6s - loss: 0.0520 - accuracy: 0.9818 - val_loss: 0.1621 - val_accuracy: 0.9508
# Epoch 49/100
#  - 6s - loss: 0.0470 - accuracy: 0.9840 - val_loss: 0.1734 - val_accuracy: 0.9528
# Epoch 50/100
#  - 6s - loss: 0.0470 - accuracy: 0.9836 - val_loss: 0.1702 - val_accuracy: 0.9510
# Epoch 51/100
#  - 6s - loss: 0.0479 - accuracy: 0.9836 - val_loss: 0.1793 - val_accuracy: 0.9510
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.0006328124727588147.
# Epoch 52/100
#  - 6s - loss: 0.0412 - accuracy: 0.9859 - val_loss: 0.1749 - val_accuracy: 0.9534
# Epoch 53/100
#  - 6s - loss: 0.0344 - accuracy: 0.9883 - val_loss: 0.1627 - val_accuracy: 0.9554
# Epoch 54/100
#  - 6s - loss: 0.0297 - accuracy: 0.9906 - val_loss: 0.1590 - val_accuracy: 0.9556
# Epoch 55/100
#  - 6s - loss: 0.0303 - accuracy: 0.9894 - val_loss: 0.1603 - val_accuracy: 0.9568
# Epoch 56/100
#  - 6s - loss: 0.0293 - accuracy: 0.9898 - val_loss: 0.1657 - val_accuracy: 0.9548
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.00047460937639698386.
# Epoch 57/100
#  - 6s - loss: 0.0243 - accuracy: 0.9916 - val_loss: 0.1624 - val_accuracy: 0.9558
# Epoch 58/100
#  - 6s - loss: 0.0223 - accuracy: 0.9925 - val_loss: 0.1657 - val_accuracy: 0.9546
# Epoch 59/100
#  - 6s - loss: 0.0202 - accuracy: 0.9937 - val_loss: 0.1613 - val_accuracy: 0.9568
# Epoch 60/100
#  - 6s - loss: 0.0184 - accuracy: 0.9940 - val_loss: 0.1626 - val_accuracy: 0.9566
# Epoch 61/100
#  - 6s - loss: 0.0188 - accuracy: 0.9938 - val_loss: 0.1654 - val_accuracy: 0.9572
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 0.0003559570322977379.
# Epoch 62/100
#  - 6s - loss: 0.0168 - accuracy: 0.9947 - val_loss: 0.1655 - val_accuracy: 0.9586
# Epoch 63/100
#  - 6s - loss: 0.0151 - accuracy: 0.9953 - val_loss: 0.1681 - val_accuracy: 0.9578
# Epoch 64/100
#  - 6s - loss: 0.0129 - accuracy: 0.9964 - val_loss: 0.1606 - val_accuracy: 0.9596
# Epoch 65/100
#  - 6s - loss: 0.0125 - accuracy: 0.9963 - val_loss: 0.1535 - val_accuracy: 0.9614
# Epoch 66/100
#  - 6s - loss: 0.0105 - accuracy: 0.9970 - val_loss: 0.1660 - val_accuracy: 0.9608
# Epoch 67/100
#  - 6s - loss: 0.0101 - accuracy: 0.9973 - val_loss: 0.1668 - val_accuracy: 0.9592
# Epoch 68/100
#  - 6s - loss: 0.0102 - accuracy: 0.9973 - val_loss: 0.1709 - val_accuracy: 0.9598
# Epoch 69/100
#  - 6s - loss: 0.0115 - accuracy: 0.9966 - val_loss: 0.1700 - val_accuracy: 0.9558
# Epoch 70/100
#  - 6s - loss: 0.0097 - accuracy: 0.9973 - val_loss: 0.1711 - val_accuracy: 0.9582
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 0.000266967763309367.
# Epoch 71/100
#  - 6s - loss: 0.0077 - accuracy: 0.9983 - val_loss: 0.1699 - val_accuracy: 0.9560
# Epoch 72/100
#  - 6s - loss: 0.0061 - accuracy: 0.9988 - val_loss: 0.1758 - val_accuracy: 0.9588
# Epoch 73/100
#  - 6s - loss: 0.0050 - accuracy: 0.9991 - val_loss: 0.1736 - val_accuracy: 0.9584
# Epoch 74/100
#  - 6s - loss: 0.0044 - accuracy: 0.9992 - val_loss: 0.1680 - val_accuracy: 0.9606
# Epoch 75/100
#  - 6s - loss: 0.0042 - accuracy: 0.9994 - val_loss: 0.1787 - val_accuracy: 0.9586
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 0.00020022581156808883.
# Epoch 76/100
#  - 6s - loss: 0.0039 - accuracy: 0.9994 - val_loss: 0.1792 - val_accuracy: 0.9594
# Epoch 77/100
#  - 6s - loss: 0.0035 - accuracy: 0.9994 - val_loss: 0.1773 - val_accuracy: 0.9606
# Epoch 78/100
#  - 6s - loss: 0.0032 - accuracy: 0.9996 - val_loss: 0.1754 - val_accuracy: 0.9606
# Epoch 79/100
#  - 6s - loss: 0.0024 - accuracy: 0.9998 - val_loss: 0.1800 - val_accuracy: 0.9606
# Epoch 80/100
#  - 6s - loss: 0.0026 - accuracy: 0.9997 - val_loss: 0.1825 - val_accuracy: 0.9608
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 0.00015016935867606662.
# Epoch 81/100
#  - 6s - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.1848 - val_accuracy: 0.9604
# Epoch 82/100
#  - 6s - loss: 0.0016 - accuracy: 0.9999 - val_loss: 0.1927 - val_accuracy: 0.9588
# Epoch 83/100
#  - 6s - loss: 0.0014 - accuracy: 0.9999 - val_loss: 0.1885 - val_accuracy: 0.9596
# Epoch 84/100
#  - 6s - loss: 0.0014 - accuracy: 0.9999 - val_loss: 0.1922 - val_accuracy: 0.9578
# Epoch 85/100
#  - 6s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1939 - val_accuracy: 0.9598
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 0.00011262702173553407.

# %%
history_plot(history)

# %%
model.load_weights(fw)
y_test2_predictions=\
model.predict(x_test2.reshape(-1,1,784))\
.argmax(axis=-1)
pylab.figure(figsize=(12,5))
pylab.scatter(range(100),y_test2[:100],s=100)
pylab.scatter(range(100),y_test2_predictions[:100],s=25)
model.evaluate(x_test2.reshape(-1,1,784),c_y_test2)
# Out:
# 5000/5000 [==============================] - 1s 116us/step
# [0.08443485952408519, 0.9787999987602234]
