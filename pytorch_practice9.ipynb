# %% [markdown]
# Reading classics [Deep Learning Models](https://nbviewer.jupyter.org/github/rasbt/deeplearning-models/blob/master/pytorch_ipynb/cnn/cnn-vgg16.ipynb)
#
# ## Code Modules, Classes & Functions

# %%
import numpy as np,pandas as pd,pylab as pl
import h5py,torch
from tensorflow import image as timage
import tensorflow_datasets as tfds
from torchvision import transforms,utils
from torch.utils.data import DataLoader as tdl
from torch.utils.data import Dataset as tds
import torch.nn as tnn
from IPython.core.magic import register_line_magic
dev=torch.device("cuda:0" \
if torch.cuda.is_available() else "cpu")

# %%
class TData(tds):
    def __init__(self,x,y): 
        self.x=torch.tensor(x,dtype=torch.float32)
        self.y=torch.tensor(y,dtype=torch.int32)
    def __getitem__(self,index):
        train_img,train_lbl=self.x[index],self.y[index]
        return train_img,train_lbl
    def __len__(self):
        return self.y.shape[0]

# %%
def prepro_display(x,y,img_size):
    x=x.reshape(-1,3,img_size,img_size)
    y=y.reshape(-1)
    shuffle_ids=np.arange(N)
    np.random.RandomState(23).shuffle(shuffle_ids)
    x,y=x[shuffle_ids],y[shuffle_ids]
    x_test,x_valid,x_train=x[:n],x[n:2*n],x[2*n:]
    y_test,y_valid,y_train=y[:n],y[n:2*n],y[2*n:]
    df=pd.DataFrame([[x_train.shape,x_valid.shape,x_test.shape],
                     [x_train.dtype,x_valid.dtype,x_test.dtype],
                     [y_train.shape,y_valid.shape,y_test.shape],
                     [y_train.dtype,y_valid.dtype,y_test.dtype]],
                    columns=['train','valid','test'],
                    index=['image shape','image type',
                           'label shape','label type'])
    display(df)
    return [[x_train,x_valid,x_test],
            [y_train,y_valid,y_test]]
def display_examples(data_loader,img_size):
    for images,labels in data_loader:  
        print('Image dimensions: %s'%str(images.shape))
        print('Label dimensions: %s'%str(labels.shape))
        n=np.random.randint(1,50)
        fig=pl.figure(figsize=(10,3))
        for i in range(n,n+5):
            ax=fig.add_subplot(1,5,i-n+1,\
            xticks=[],yticks=[],title=labels[i].item())
            ax.imshow((images[i]).reshape(img_size,img_size,3))
        break

# %%
def model_acc(model,data_loader):
    model.eval()
    correct_preds,num_examples=0,0    
    for features,targets in data_loader:
        features=features.to(dev)
        targets=targets.to(dev)
        logits,probs=model(features)
        _,pred_labels=torch.max(probs,1)
        num_examples+=targets.size(0)
        correct_preds+=(pred_labels==targets).sum()        
    return correct_preds.float()/num_examples*100
@register_line_magic
def print_acc(n):
    if int(n)==1:
        data_loader=\
        [train_loader,valid_loader,test_loader]
    if int(n)==2:
        data_loader=\
        [train_loader2,valid_loader2,test_loader2]
    print('Train accuracy: %.4f%%'%\
    (model_acc(model,data_loader[0])))
    print('Valid accuracy: %.4f%%'%\
    (model_acc(model,data_loader[1])))
    print('Test accuracy: %.4f%%'%\
    (model_acc(model,data_loader[2])))

# %% [markdown]
# ## Data

# %%
splits='train'
tfds.disable_progress_bar()
(raws),metadata=\
tfds.load('cats_vs_dogs:4.0.0',split=splits,
          with_info=True,as_supervised=True)

# %%
img_size=32; N=23262; n=int(.2*N); i=0
images=np.zeros((N,img_size,img_size,3),
                dtype='float32')
labels=np.zeros((N,1),dtype='int32')
for img,lbl in raws.take(N):
    img=timage.resize(img,[img_size,img_size])
    images[i,:]=img.numpy()/255
    labels[i,:]=lbl; i+=1

# %%
[[x_train,x_valid,x_test],
 [y_train,y_valid,y_test]]=\
prepro_display(images,labels,img_size)
# Out:
#                           train              valid               test
# image shape  (13958, 3, 32, 32)  (4652, 3, 32, 32)  (4652, 3, 32, 32)
# image type              float32            float32            float32
# label shape            (13958,)            (4652,)            (4652,)
# label type                int32              int32              int32

# %%
random_seed=12; batch_size=128
train=TData(x_train,y_train)
valid=TData(x_valid,y_valid)
test=TData(x_test,y_test)
train_loader=tdl(dataset=train,shuffle=True,
                 batch_size=batch_size)
valid_loader=tdl(dataset=valid,shuffle=True,
                 batch_size=batch_size)
test_loader=tdl(dataset=test,shuffle=True,
                 batch_size=batch_size)
display_examples(valid_loader,img_size)
# Out:
# Image dimensions: torch.Size([128, 3, 32, 32])
# Label dimensions: torch.Size([128])

# %% [markdown]
# ## VGG16

# %%
class VGG16(tnn.Module):
    def __init__(self,num_classes):
        super(VGG16,self).__init__()
        self.block1=tnn.Sequential(
            tnn.Conv2d(in_channels=3,out_channels=64,
                       kernel_size=(3,3),stride=(1,1),
                       padding=1), 
            tnn.ReLU(),
            tnn.Conv2d(in_channels=64,out_channels=64,
                       kernel_size=(3,3),stride=(1,1),
                       padding=1),
            tnn.ReLU(),
            tnn.MaxPool2d(kernel_size=(2,2),
                          stride=(2,2)) )       
        self.block2=tnn.Sequential(
            tnn.Conv2d(in_channels=64,out_channels=128,
                       kernel_size=(3,3),stride=(1,1),
                       padding=1),
            tnn.ReLU(),
            tnn.Conv2d(in_channels=128,out_channels=128,
                       kernel_size=(3,3),stride=(1,1),
                       padding=1),
            tnn.ReLU(),
            tnn.MaxPool2d(kernel_size=(2,2),
                          stride=(2,2)) )
        self.block3=tnn.Sequential(
            tnn.Conv2d(in_channels=128,out_channels=256,
                       kernel_size=(3,3),stride=(1,1),
                       padding=1),
            tnn.ReLU(),
            tnn.Conv2d(in_channels=256,out_channels=256,
                       kernel_size=(3,3),stride=(1,1),
                       padding=1),
            tnn.ReLU(),        
            tnn.Conv2d(in_channels=256,out_channels=256,
                       kernel_size=(3,3),stride=(1,1),
                       padding=1),
            tnn.ReLU(),
            tnn.Conv2d(in_channels=256,out_channels=256,
                       kernel_size=(3,3),stride=(1,1),
                       padding=1),
            tnn.ReLU(),
            tnn.MaxPool2d(kernel_size=(2,2),
                          stride=(2,2)) )                  
        self.block4=tnn.Sequential(
            tnn.Conv2d(in_channels=256,out_channels=512,
                       kernel_size=(3,3),stride=(1,1),
                       padding=1),
            tnn.ReLU(),        
            tnn.Conv2d(in_channels=512,out_channels=512,
                       kernel_size=(3,3),stride=(1,1),
                       padding=1),
            tnn.ReLU(),        
            tnn.Conv2d(in_channels=512,out_channels=512,
                       kernel_size=(3,3),stride=(1,1),
                       padding=1),
            tnn.ReLU(),
            tnn.Conv2d(in_channels=512,out_channels=512,
                       kernel_size=(3,3),stride=(1,1),
                       padding=1),
            tnn.ReLU(),   
            tnn.MaxPool2d(kernel_size=(2,2),
                          stride=(2,2)) )        
        self.block5=tnn.Sequential(
            tnn.Conv2d(in_channels=512,out_channels=512,
                       kernel_size=(3,3),stride=(1,1),
                       padding=1),
            tnn.ReLU(),            
            tnn.Conv2d(in_channels=512,out_channels=512,
                       kernel_size=(3,3),stride=(1,1),
                       padding=1),
            tnn.ReLU(),            
            tnn.Conv2d(in_channels=512,out_channels=512,
                       kernel_size=(3,3),stride=(1,1),
                       padding=1),
            tnn.ReLU(),
            tnn.Conv2d(in_channels=512,out_channels=512,
                       kernel_size=(3,3),stride=(1,1),
                       padding=1),
            tnn.ReLU(),   
            tnn.MaxPool2d(kernel_size=(2,2),
                          stride=(2,2)) )        
        self.classifier=tnn.Sequential(
            tnn.Linear(512,4096),tnn.ReLU(),   
            tnn.Linear(4096,4096),tnn.ReLU(),
            tnn.Linear(4096,num_classes) )        
        for m in self.modules():
            if isinstance(m, torch.nn.Conv2d):
                m.weight.detach().normal_(0,.05)
                if m.bias is not None:
                    m.bias.detach().zero_()
            elif isinstance(m,torch.nn.Linear):
                m.weight.detach().normal_(0,.05)
                m.bias.detach().detach().zero_()               
    def forward(self,x):
        x=self.block1(x)
        x=self.block2(x)
        x=self.block3(x)
        x=self.block4(x)
        x=self.block5(x)
        logits=self.classifier(x.view(-1,512))
        probs=tnn.functional.softmax(logits,dim=1)
        return logits,probs

# %% [markdown]
# ## Training

# %%
num_classes=2; learning_rate=.001
model=VGG16(num_classes)
model.to(dev)
optimizer=torch.optim.Adam(model.parameters(),
                           lr=learning_rate)

# %%
@register_line_magic
def train_run(epochs):
    epochs=int(epochs)
    for epoch in range(epochs):
        model.train()
        for batch_ids,(features,targets) in enumerate(train_loader):        
            features=features.to(dev); targets=targets.to(dev)
            logits,probs=model(features)
            cost=tnn.functional.cross_entropy(logits,targets.long())
            optimizer.zero_grad(); cost.backward()
            optimizer.step()
            if not batch_ids%50:
                print ('Epoch: %03d/%03d | Batch %03d/%03d | Cost: %.4f' 
                       %(epoch+1,epochs,batch_ids, 
                         len(train)//batch_size,cost))
        model.eval()         
        with torch.set_grad_enabled(False):
            print('Epoch: %03d/%03d train acc: %.2f%% valid acc: %.2f%%'%\
                  (epoch+1,epochs,
                   model_acc(model,train_loader),
                   model_acc(model,valid_loader)))

# %%
# %train_run 50
# Out:
# Epoch: 001/050 | Batch 000/109 | Cost: 939.4967
# Epoch: 001/050 | Batch 050/109 | Cost: 0.7093
# Epoch: 001/050 | Batch 100/109 | Cost: 0.6896
# Epoch: 001/050 train acc: 50.19% valid acc: 51.48%
# Epoch: 002/050 | Batch 000/109 | Cost: 0.7295
# Epoch: 002/050 | Batch 050/109 | Cost: 0.6732
# Epoch: 002/050 | Batch 100/109 | Cost: 0.6797
# Epoch: 002/050 train acc: 55.60% valid acc: 54.75%
# Epoch: 003/050 | Batch 000/109 | Cost: 0.6822
# Epoch: 003/050 | Batch 050/109 | Cost: 0.6866
# Epoch: 003/050 | Batch 100/109 | Cost: 0.6824
# Epoch: 003/050 train acc: 59.86% valid acc: 58.68%
# Epoch: 004/050 | Batch 000/109 | Cost: 0.6783
# Epoch: 004/050 | Batch 050/109 | Cost: 0.6880
# Epoch: 004/050 | Batch 100/109 | Cost: 0.7754
# Epoch: 004/050 train acc: 53.44% valid acc: 51.78%
# Epoch: 005/050 | Batch 000/109 | Cost: 0.6868
# Epoch: 005/050 | Batch 050/109 | Cost: 0.6779
# Epoch: 005/050 | Batch 100/109 | Cost: 0.6804
# Epoch: 005/050 train acc: 50.91% valid acc: 49.96%
# Epoch: 006/050 | Batch 000/109 | Cost: 0.6701
# Epoch: 006/050 | Batch 050/109 | Cost: 0.6791
# Epoch: 006/050 | Batch 100/109 | Cost: 0.6659
# Epoch: 006/050 train acc: 52.24% valid acc: 51.10%
# Epoch: 007/050 | Batch 000/109 | Cost: 0.6484
# Epoch: 007/050 | Batch 050/109 | Cost: 0.6776
# Epoch: 007/050 | Batch 100/109 | Cost: 0.7011
# Epoch: 007/050 train acc: 59.88% valid acc: 58.06%
# Epoch: 008/050 | Batch 000/109 | Cost: 0.6695
# Epoch: 008/050 | Batch 050/109 | Cost: 0.6706
# Epoch: 008/050 | Batch 100/109 | Cost: 0.6808
# Epoch: 008/050 train acc: 50.19% valid acc: 51.48%
# Epoch: 009/050 | Batch 000/109 | Cost: 0.7138
# Epoch: 009/050 | Batch 050/109 | Cost: 0.7033
# Epoch: 009/050 | Batch 100/109 | Cost: 0.6511
# Epoch: 009/050 train acc: 57.78% valid acc: 56.06%
# Epoch: 010/050 | Batch 000/109 | Cost: 0.6940
# Epoch: 010/050 | Batch 050/109 | Cost: 0.6618
# Epoch: 010/050 | Batch 100/109 | Cost: 0.6328
# Epoch: 010/050 train acc: 55.34% valid acc: 53.89%
# Epoch: 011/050 | Batch 000/109 | Cost: 0.6883
# Epoch: 011/050 | Batch 050/109 | Cost: 0.6956
# Epoch: 011/050 | Batch 100/109 | Cost: 0.6711
# Epoch: 011/050 train acc: 57.50% valid acc: 57.44%
# Epoch: 012/050 | Batch 000/109 | Cost: 0.7018
# Epoch: 012/050 | Batch 050/109 | Cost: 0.6735
# Epoch: 012/050 | Batch 100/109 | Cost: 0.6591
# Epoch: 012/050 train acc: 53.32% valid acc: 52.04%
# Epoch: 013/050 | Batch 000/109 | Cost: 0.6690
# Epoch: 013/050 | Batch 050/109 | Cost: 0.6797
# Epoch: 013/050 | Batch 100/109 | Cost: 0.6613
# Epoch: 013/050 train acc: 62.27% valid acc: 61.56%
# Epoch: 014/050 | Batch 000/109 | Cost: 0.6382
# Epoch: 014/050 | Batch 050/109 | Cost: 0.6560
# Epoch: 014/050 | Batch 100/109 | Cost: 0.6855
# Epoch: 014/050 train acc: 64.97% valid acc: 62.94%
# Epoch: 015/050 | Batch 000/109 | Cost: 0.6289
# Epoch: 015/050 | Batch 050/109 | Cost: 0.7013
# Epoch: 015/050 | Batch 100/109 | Cost: 0.5818
# Epoch: 015/050 train acc: 58.57% valid acc: 57.33%
# Epoch: 016/050 | Batch 000/109 | Cost: 0.6530
# Epoch: 016/050 | Batch 050/109 | Cost: 0.5892
# Epoch: 016/050 | Batch 100/109 | Cost: 0.5845
# Epoch: 016/050 train acc: 65.03% valid acc: 62.08%
# Epoch: 017/050 | Batch 000/109 | Cost: 0.6765
# Epoch: 017/050 | Batch 050/109 | Cost: 0.6405
# Epoch: 017/050 | Batch 100/109 | Cost: 0.6150
# Epoch: 017/050 train acc: 67.51% valid acc: 63.65%
# Epoch: 018/050 | Batch 000/109 | Cost: 0.6168
# Epoch: 018/050 | Batch 050/109 | Cost: 0.6934
# Epoch: 018/050 | Batch 100/109 | Cost: 0.6396
# Epoch: 018/050 train acc: 64.39% valid acc: 60.62%
# Epoch: 019/050 | Batch 000/109 | Cost: 0.6328
# Epoch: 019/050 | Batch 050/109 | Cost: 0.6807
# Epoch: 019/050 | Batch 100/109 | Cost: 0.6394
# Epoch: 019/050 train acc: 67.72% valid acc: 63.46%
# Epoch: 020/050 | Batch 000/109 | Cost: 0.5850
# Epoch: 020/050 | Batch 050/109 | Cost: 0.5807
# Epoch: 020/050 | Batch 100/109 | Cost: 0.5807
# Epoch: 020/050 train acc: 69.09% valid acc: 63.93%
# Epoch: 021/050 | Batch 000/109 | Cost: 0.6324
# Epoch: 021/050 | Batch 050/109 | Cost: 0.5577
# Epoch: 021/050 | Batch 100/109 | Cost: 0.6256
# Epoch: 021/050 train acc: 67.22% valid acc: 62.62%
# Epoch: 022/050 | Batch 000/109 | Cost: 0.6935
# Epoch: 022/050 | Batch 050/109 | Cost: 0.6506
# Epoch: 022/050 | Batch 100/109 | Cost: 0.6197
# Epoch: 022/050 train acc: 67.92% valid acc: 62.53%
# Epoch: 023/050 | Batch 000/109 | Cost: 0.6009
# Epoch: 023/050 | Batch 050/109 | Cost: 0.6324
# Epoch: 023/050 | Batch 100/109 | Cost: 0.7074
# Epoch: 023/050 train acc: 70.52% valid acc: 63.35%
# Epoch: 024/050 | Batch 000/109 | Cost: 0.5308
# Epoch: 024/050 | Batch 050/109 | Cost: 0.6003
# Epoch: 024/050 | Batch 100/109 | Cost: 0.5483
# Epoch: 024/050 train acc: 72.08% valid acc: 63.28%
# Epoch: 025/050 | Batch 000/109 | Cost: 0.5478
# Epoch: 025/050 | Batch 050/109 | Cost: 0.5745
# Epoch: 025/050 | Batch 100/109 | Cost: 0.4791
# Epoch: 025/050 train acc: 70.17% valid acc: 63.39%
# Epoch: 026/050 | Batch 000/109 | Cost: 0.5890
# Epoch: 026/050 | Batch 050/109 | Cost: 0.5423
# Epoch: 026/050 | Batch 100/109 | Cost: 0.5760
# Epoch: 026/050 train acc: 74.78% valid acc: 64.32%
# Epoch: 027/050 | Batch 000/109 | Cost: 0.4972
# Epoch: 027/050 | Batch 050/109 | Cost: 0.5397
# Epoch: 027/050 | Batch 100/109 | Cost: 0.6449
# Epoch: 027/050 train acc: 70.40% valid acc: 63.07%
# Epoch: 028/050 | Batch 000/109 | Cost: 0.6171
# Epoch: 028/050 | Batch 050/109 | Cost: 0.4956
# Epoch: 028/050 | Batch 100/109 | Cost: 0.5454
# Epoch: 028/050 train acc: 73.85% valid acc: 63.01%
# Epoch: 029/050 | Batch 000/109 | Cost: 0.6134
# Epoch: 029/050 | Batch 050/109 | Cost: 0.5844
# Epoch: 029/050 | Batch 100/109 | Cost: 0.5774
# Epoch: 029/050 train acc: 74.42% valid acc: 64.60%
# Epoch: 030/050 | Batch 000/109 | Cost: 0.4866
# Epoch: 030/050 | Batch 050/109 | Cost: 0.4760
# Epoch: 030/050 | Batch 100/109 | Cost: 0.5032
# Epoch: 030/050 train acc: 77.58% valid acc: 64.04%
# Epoch: 031/050 | Batch 000/109 | Cost: 0.4311
# Epoch: 031/050 | Batch 050/109 | Cost: 0.4976
# Epoch: 031/050 | Batch 100/109 | Cost: 0.5450
# Epoch: 031/050 train acc: 75.59% valid acc: 64.02%
# Epoch: 032/050 | Batch 000/109 | Cost: 0.4691
# Epoch: 032/050 | Batch 050/109 | Cost: 0.4850
# Epoch: 032/050 | Batch 100/109 | Cost: 0.4677
# Epoch: 032/050 train acc: 72.22% valid acc: 59.61%
# Epoch: 033/050 | Batch 000/109 | Cost: 0.5903
# Epoch: 033/050 | Batch 050/109 | Cost: 0.4212
# Epoch: 033/050 | Batch 100/109 | Cost: 0.5149
# Epoch: 033/050 train acc: 78.36% valid acc: 64.49%
# Epoch: 034/050 | Batch 000/109 | Cost: 0.4785
# Epoch: 034/050 | Batch 050/109 | Cost: 0.5353
# Epoch: 034/050 | Batch 100/109 | Cost: 0.4964
# Epoch: 034/050 train acc: 76.67% valid acc: 62.64%
# Epoch: 035/050 | Batch 000/109 | Cost: 0.5075
# Epoch: 035/050 | Batch 050/109 | Cost: 0.4952
# Epoch: 035/050 | Batch 100/109 | Cost: 0.3597
# Epoch: 035/050 train acc: 79.47% valid acc: 62.15%
# Epoch: 036/050 | Batch 000/109 | Cost: 0.4416
# Epoch: 036/050 | Batch 050/109 | Cost: 0.4255
# Epoch: 036/050 | Batch 100/109 | Cost: 0.4111
# Epoch: 036/050 train acc: 79.67% valid acc: 62.36%
# Epoch: 037/050 | Batch 000/109 | Cost: 0.4881
# Epoch: 037/050 | Batch 050/109 | Cost: 0.4676
# Epoch: 037/050 | Batch 100/109 | Cost: 0.4730
# Epoch: 037/050 train acc: 81.37% valid acc: 61.61%
# Epoch: 038/050 | Batch 000/109 | Cost: 0.3303
# Epoch: 038/050 | Batch 050/109 | Cost: 0.4020
# Epoch: 038/050 | Batch 100/109 | Cost: 0.3728
# Epoch: 038/050 train acc: 81.42% valid acc: 60.83%
# Epoch: 039/050 | Batch 000/109 | Cost: 0.4040
# Epoch: 039/050 | Batch 050/109 | Cost: 0.3584
# Epoch: 039/050 | Batch 100/109 | Cost: 0.4166
# Epoch: 039/050 train acc: 85.61% valid acc: 62.98%
# Epoch: 040/050 | Batch 000/109 | Cost: 0.3364
# Epoch: 040/050 | Batch 050/109 | Cost: 0.3879
# Epoch: 040/050 | Batch 100/109 | Cost: 0.3946
# Epoch: 040/050 train acc: 82.98% valid acc: 63.46%
# Epoch: 041/050 | Batch 000/109 | Cost: 0.3592
# Epoch: 041/050 | Batch 050/109 | Cost: 0.6163
# Epoch: 041/050 | Batch 100/109 | Cost: 0.5073
# Epoch: 041/050 train acc: 72.67% valid acc: 61.46%
# Epoch: 042/050 | Batch 000/109 | Cost: 0.5447
# Epoch: 042/050 | Batch 050/109 | Cost: 0.4467
# Epoch: 042/050 | Batch 100/109 | Cost: 0.4323
# Epoch: 042/050 train acc: 83.41% valid acc: 63.07%
# Epoch: 043/050 | Batch 000/109 | Cost: 0.3925
# Epoch: 043/050 | Batch 050/109 | Cost: 0.3217
# Epoch: 043/050 | Batch 100/109 | Cost: 0.2843
# Epoch: 043/050 train acc: 86.87% valid acc: 63.52%
# Epoch: 044/050 | Batch 000/109 | Cost: 0.2946
# Epoch: 044/050 | Batch 050/109 | Cost: 0.3347
# Epoch: 044/050 | Batch 100/109 | Cost: 0.3159
# Epoch: 044/050 train acc: 86.70% valid acc: 63.50%
# Epoch: 045/050 | Batch 000/109 | Cost: 0.3222
# Epoch: 045/050 | Batch 050/109 | Cost: 0.2330
# Epoch: 045/050 | Batch 100/109 | Cost: 0.2598
# Epoch: 045/050 train acc: 92.77% valid acc: 63.07%
# Epoch: 046/050 | Batch 000/109 | Cost: 0.2122
# Epoch: 046/050 | Batch 050/109 | Cost: 0.3392
# Epoch: 046/050 | Batch 100/109 | Cost: 0.2280
# Epoch: 046/050 train acc: 91.49% valid acc: 62.53%
# Epoch: 047/050 | Batch 000/109 | Cost: 0.2263
# Epoch: 047/050 | Batch 050/109 | Cost: 0.3625
# Epoch: 047/050 | Batch 100/109 | Cost: 0.2497
# Epoch: 047/050 train acc: 93.74% valid acc: 63.05%
# Epoch: 048/050 | Batch 000/109 | Cost: 0.1190
# Epoch: 048/050 | Batch 050/109 | Cost: 0.2450
# Epoch: 048/050 | Batch 100/109 | Cost: 0.2236
# Epoch: 048/050 train acc: 89.65% valid acc: 62.47%
# Epoch: 049/050 | Batch 000/109 | Cost: 0.1806
# Epoch: 049/050 | Batch 050/109 | Cost: 0.1959
# Epoch: 049/050 | Batch 100/109 | Cost: 0.2229
# Epoch: 049/050 train acc: 93.62% valid acc: 63.80%
# Epoch: 050/050 | Batch 000/109 | Cost: 0.1691
# Epoch: 050/050 | Batch 050/109 | Cost: 0.2331
# Epoch: 050/050 | Batch 100/109 | Cost: 0.2126
# Epoch: 050/050 train acc: 93.63% valid acc: 63.13%

# %%
# %print_acc 1
# Out:
# Train accuracy: 93.6309%
# Valid accuracy: 63.1341%
# Test accuracy: 62.3173%
