# %%
import random; from IPython.display import display,HTML
from IPython.core.magic import register_line_magic
import warnings; warnings.filterwarnings('ignore')
import pandas as pd,numpy as np,pylab as pl
import tensorflow as tf,sklearn.model_selection as sms
from sklearn import datasets
from tensorflow.data import Dataset as tds

# %%
@register_line_magic
def radial_gradient_header(params):
    randi=str(random.randint(1,9999999))
    params=params.split('|'); string=params[0]
    if len(params)==1: font_size=str(30); font_family='Ewert'
    elif len(params)==2: font_size=params[1]; font_family='Ewert'
    else: font_size=params[1]; font_family=params[2]
    html_str="""<style>
    @import 'https://fonts.googleapis.com/css?family="""+font_family+"""'; 
    #div"""+randi+""" {background:white; padding:2px;}
    .rgtext {display:inline-block; padding:5px; font-size:"""+font_size+"""px; 
             line-height:1.1; font-family:"""+font_family+""",sans-serif; 
             text-transform:uppercase;
             background:radial-gradient(
                 circle farthest-corner at center center,
                 orange,magenta,cyan) no-repeat;
            -webkit-background-clip:text;
            -webkit-text-fill-color:transparent;}
    </style><div id='div"""+randi+"""'>
    <text class='rgtext'>"""+string+"""</text></div>"""
    display(HTML(html_str))
@register_line_magic
def df_num_style(line_num):
    global df_num,numeric_features
    stats=df_num.describe().transpose()
    for nc in numeric_features:
        mean=stats.loc[nc,'mean']; std=stats.loc[nc,'std']
        df_num.loc[:,nc]=(df_num.loc[:,nc]-mean)/std
    style_dict=[dict(selector='th',
                     props=[('font-size','10pt'),('min-width','45px')]),
                dict(selector='td',
                     props=[('padding','0em 0em'),('min-width','45px')]),
                dict(selector='tr:hover th:hover',
                     props=[('font-size','11pt'),('max-width','45px'),
                            ('text-shadow','3px 3px 3px #aaa')]),
                dict(selector='tr:hover td:hover',
                     props=[('font-size','10pt'),('max-width','45px'),
                            ('text-shadow','3px 3px 3px #aaa')])]
    display(df_num[numeric_features].tail(int(line_num))
            .style.bar(align='mid',color=['#55eeee','#ee55ee'],
                       subset=numeric_features).set_precision(3)\
            .set_table_styles(style_dict))

# %%
# %radial_gradient_header Data Exploration
# Out:
# <style>
#     @import 'https://fonts.googleapis.com/css?family=Ewert';
#     #div5350261 {background:white; padding:2px;}
#     .rgtext {display:inline-block; padding:5px; font-size:30px;
#              line-height:1.1; font-family:Ewert,sans-serif;
#              text-transform:uppercase;
#              background:radial-gradient(
#                  circle farthest-corner at center center,
#                  orange,magenta,cyan) no-repeat;
#             -webkit-background-clip:text;
#             -webkit-text-fill-color:transparent;}
#     </style><div id='div5350261'>
#     <text class='rgtext'>Data Exploration</text></div>

# %%
boston_data=datasets.load_boston()
boston_df=pd.DataFrame(
    boston_data.data,columns=boston_data.feature_names)
boston_df['MEDV']=boston_data.target
boston_df[['CHAS','RAD']]=boston_df[['CHAS','RAD']].astype('int64')
numeric_features=boston_df.columns[[0,2,4,5,6,7,9,10,11,12,13]]
df_num=boston_df.copy()
# %df_num_style 10
# Out:
# <style  type="text/css" >
#     #T_58b7420c_8c91_11eb_a180_0242ac1c0002 th {
#           font-size: 10pt;
#           min-width: 45px;
#     }    #T_58b7420c_8c91_11eb_a180_0242ac1c0002 td {
#           padding: 0em 0em;
#           min-width: 45px;
#     }    #T_58b7420c_8c91_11eb_a180_0242ac1c0002 tr:hover th:hover {
#           font-size: 11pt;
#           max-width: 45px;
#           text-shadow: 3px 3px 3px #aaa;
#     }    #T_58b7420c_8c91_11eb_a180_0242ac1c0002 tr:hover td:hover {
#           font-size: 10pt;
#           max-width: 45px;
#           text-shadow: 3px 3px 3px #aaa;
#     }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 6.8%, #55eeee 6.8%, #55eeee 100.0%, transparent 100.0%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row0_col1,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row1_col1,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row2_col1,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row3_col1,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#55eeee 64.6%, transparent 64.6%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row0_col2,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row0_col8,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row1_col2,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row1_col8,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row2_col2,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row2_col8,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row3_col2,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row4_col2,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row4_col8,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row5_col7,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row6_col7,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row6_col8,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row7_col7,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row7_col8,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row8_col7,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row9_col7,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row9_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee55ee 100.0%, transparent 100.0%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row0_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#55eeee 56.4%, transparent 56.4%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.7%, #ee55ee 12.7%, #ee55ee 29.6%, transparent 29.6%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 38.8%, #55eeee 38.8%, #55eeee 100.0%, transparent 100.0%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row0_col6,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row1_col6,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row2_col6,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row3_col6,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row4_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 87.3%, #55eeee 87.3%, #55eeee 100.0%, transparent 100.0%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row0_col7,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row1_col7,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row2_col7,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row3_col7,#T_58b7420c_8c91_11eb_a180_0242ac1c0002row4_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee55ee 29.3%, transparent 29.3%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row0_col9{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.2%, #ee55ee 45.2%, #ee55ee 100.0%, transparent 100.0%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row0_col10{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 65.0%, #55eeee 65.0%, #55eeee 88.6%, transparent 88.6%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 6.3%, #55eeee 6.3%, #55eeee 100.0%, transparent 100.0%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.5%, #55eeee 25.5%, #55eeee 56.4%, transparent 56.4%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.7%, #ee55ee 12.7%, #ee55ee 20.6%, transparent 20.6%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.6%, #55eeee 44.6%, #55eeee 100.0%, transparent 100.0%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row1_col9{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.2%, #ee55ee 45.2%, #ee55ee 54.6%, transparent 54.6%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row1_col10{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 53.3%, #55eeee 53.3%, #55eeee 88.6%, transparent 88.6%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 5.4%, #55eeee 5.4%, #55eeee 100.0%, transparent 100.0%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 39.7%, #55eeee 39.7%, #55eeee 56.4%, transparent 56.4%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#55eeee 12.7%, transparent 12.7%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 14.8%, #55eeee 14.8%, #55eeee 100.0%, transparent 100.0%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row2_col9{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.2%, #ee55ee 45.2%, #ee55ee 47.0%, transparent 47.0%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row2_col10{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 77.5%, #55eeee 77.5%, #55eeee 88.6%, transparent 88.6%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 3.7%, #55eeee 3.7%, #55eeee 100.0%, transparent 100.0%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 11.3%, #55eeee 11.3%, #55eeee 56.4%, transparent 56.4%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.7%, #ee55ee 12.7%, #ee55ee 31.9%, transparent 31.9%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 14.3%, #55eeee 14.3%, #55eeee 100.0%, transparent 100.0%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row3_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee55ee 97.2%, transparent 97.2%);
#         }#T_58b7420c_8c91_11eb_a180_0242ac1c0002row3_col9{
#             width

# %%
# %radial_gradient_header Data Processing
# Out:
# <style>
#     @import 'https://fonts.googleapis.com/css?family=Ewert';
#     #div9374656 {background:white; padding:2px;}
#     .rgtext {display:inline-block; padding:5px; font-size:30px;
#              line-height:1.1; font-family:Ewert,sans-serif;
#              text-transform:uppercase;
#              background:radial-gradient(
#                  circle farthest-corner at center center,
#                  orange,magenta,cyan) no-repeat;
#             -webkit-background-clip:text;
#             -webkit-text-fill-color:transparent;}
#     </style><div id='div9374656'>
#     <text class='rgtext'>Data Processing</text></div>

# %%
tfnumeric_features=[]
for nc in numeric_features[:-1]:
    tfnumeric_features.append(
        tf.feature_column.numeric_column(key=nc)) 
for nf in tfnumeric_features: 
    print(str(nf)); break
fchas=tf.feature_column.categorical_column_with_vocabulary_list(
    key='CHAS',vocabulary_list=[0,1])
frad=tf.feature_column.categorical_column_with_vocabulary_list(
    key='RAD',vocabulary_list=[1,2,3,4,5,6,7,8,24])
tfcategorical_features=[]
fchas_emb=tf.feature_column.embedding_column(fchas,dimension=2)
tfcategorical_features.append(fchas_emb)
frad_emb=tf.feature_column.embedding_column(frad,dimension=9)
tfcategorical_features.append(frad_emb)
print(str(tfcategorical_features[0]))
fzn=tf.feature_column.numeric_column(key='ZN')
tfbucketized_features=[tf.feature_column.bucketized_column(
    source_column=fzn,boundaries=[30,70,100])]
print(str(tfbucketized_features[0]))
# Out:
# NumericColumn(key='CRIM', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)
# EmbeddingColumn(categorical_column=VocabularyListCategoricalColumn(key='CHAS', vocabulary_list=(0, 1), dtype=tf.int64, default_value=-1, num_oov_buckets=0), dimension=2, combiner='mean', initializer=<tensorflow.python.ops.init_ops.TruncatedNormal object at 0x7f5b42291410>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True, use_safe_embedding_lookup=True)
# BucketizedColumn(source_column=NumericColumn(key='ZN', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(30, 70, 100))

# %%
features=(tfnumeric_features+tfbucketized_features+tfcategorical_features)
dfn_train,dfn_test=sms.train_test_split(df_num,train_size=.8,shuffle=True)
print(str([len(dfn_train),len(dfn_test)]))
# Out:
# [404, 102]

# %%
batch_size=8
def train_input_fn(dfn_train,batch_size):
    dft=dfn_train.copy()
    x_train,y_train=dft,dft.pop('MEDV')
    ds_train=tds.from_tensor_slices((dict(x_train),y_train))
    return ds_train.shuffle(len(x_train)).repeat().batch(batch_size)
ds_train=train_input_fn(dfn_train,batch_size)
batch=next(iter(ds_train))
print('keys: \n%s'%batch[0].keys())
print('batch values of `ZN`: \n %s'%batch[0]['ZN'])
# Out:
# keys:
# dict_keys(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT'])
# batch values of `ZN`:
#  tf.Tensor([ 0.  0.  0.  0.  0. 75.  0. 20.], shape=(8,), dtype=float64)

# %%
def test_input_fn(dfn_test,batch_size):
    dft2=dfn_test.copy()
    x_test,y_test=dft2,dft2.pop('MEDV')
    ds_test=tds.from_tensor_slices((dict(x_test),y_test))
    return ds_test.batch(batch_size)
ds_test=test_input_fn(dfn_test,batch_size)
batch=next(iter(ds_test))
print('keys: \n%s'%batch[0].keys())
print('batch values of `CHAS`: \n%s'%batch[0]['CHAS'])
# Out:
# keys:
# dict_keys(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT'])
# batch values of `CHAS`:
# tf.Tensor([0 0 0 0 0 0 0 0], shape=(8,), dtype=int64)

# %%
# %radial_gradient_header Model Training
# Out:
# <style>
#     @import 'https://fonts.googleapis.com/css?family=Ewert';
#     #div8237780 {background:white; padding:2px;}
#     .rgtext {display:inline-block; padding:5px; font-size:30px;
#              line-height:1.1; font-family:Ewert,sans-serif;
#              text-transform:uppercase;
#              background:radial-gradient(
#                  circle farthest-corner at center center,
#                  orange,magenta,cyan) no-repeat;
#             -webkit-background-clip:text;
#             -webkit-text-fill-color:transparent;}
#     </style><div id='div8237780'>
#     <text class='rgtext'>Model Training</text></div>

# %%
reg=tf.estimator.DNNRegressor(
    feature_columns=features,hidden_units=[104,52],
    model_dir='models/boston-dnnregressor/');
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'models/boston-dnnregressor/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
epochs=1000
steps=epochs*int(np.ceil(len(dfn_train)/batch_size))
print('training steps: %d'%steps)
reg.train(input_fn=lambda:train_input_fn(dfn_train,batch_size),steps=steps);
# Out:
# training steps: 51000
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/adagrad.py:83: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 
 (0.133 sec)
# INFO:tensorflow:global_step/sec: 842.446
# INFO:tensorflow:loss = 0.020411165, step = 50100 (0.121 sec)
# INFO:tensorflow:global_step/sec: 804.44
# INFO:tensorflow:loss = 0.020636918, step = 50200 (0.125 sec)
# INFO:tensorflow:global_step/sec: 818.843
# INFO:tensorflow:loss = 0.048357055, step = 50300 (0.119 sec)
# INFO:tensorflow:global_step/sec: 771.838
# INFO:tensorflow:loss = 0.030719478, step = 50400 (0.138 sec)
# INFO:tensorflow:global_step/sec: 757.434
# INFO:tensorflow:loss = 0.025904208, step = 50500 (0.124 sec)
# INFO:tensorflow:global_step/sec: 801.146
# INFO:tensorflow:loss = 0.06831756, step = 50600 (0.125 sec)
# INFO:tensorflow:global_step/sec: 769.488
# INFO:tensorflow:loss = 0.020320699, step = 50700 (0.130 sec)
# INFO:tensorflow:global_step/sec: 754.675
# INFO:tensorflow:loss = 0.024918048, step = 50800 (0.137 sec)
# INFO:tensorflow:global_step/sec: 770.249
# INFO:tensorflow:loss = 0.048115198, step = 50900 (0.126 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 51000...
# INFO:tensorflow:Saving checkpoints for 51000 into models/boston-dnnregressor/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 51000...
# INFO:tensorflow:Loss for final step: 0.07539863.

# %%
# %radial_gradient_header Model Evaluation
# Out:
# <style>
#     @import 'https://fonts.googleapis.com/css?family=Ewert';
#     #div1532875 {background:white; padding:2px;}
#     .rgtext {display:inline-block; padding:5px; font-size:30px;
#              line-height:1.1; font-family:Ewert,sans-serif;
#              text-transform:uppercase;
#              background:radial-gradient(
#                  circle farthest-corner at center center,
#                  orange,magenta,cyan) no-repeat;
#             -webkit-background-clip:text;
#             -webkit-text-fill-color:transparent;}
#     </style><div id='div1532875'>
#     <text class='rgtext'>Model Evaluation</text></div>

# %%
reloaded_reg=tf.estimator.DNNRegressor(
    feature_columns=features,hidden_units=[104,52],
    warm_start_from='models/boston-dnnregressor/',
    model_dir='models/boston-dnnregressor/');
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'models/boston-dnnregressor/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
test_results=reloaded_reg.evaluate(
    input_fn=lambda:test_input_fn(dfn_test,batch_size))
for key in test_results:
    print('{}: {}'.format(key,test_results[key]))
print('test average loss% {:.4f}'\
      .format(test_results['average_loss']))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-03-24T11:10:13Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/boston-dnnregressor/model.ckpt-51000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.36141s
# INFO:tensorflow:Finished evaluation at 2021-03-24-11:10:13
# INFO:tensorflow:Saving dict for global step 51000: average_loss = 0.15226857, global_step = 51000, label/mean = 0.057833377, loss = 0.15022503, prediction/mean = 0.06774491
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 51000: models/boston-dnnregressor/model.ckpt-51000
# average_loss: 0.15226857364177704
# label/mean: 0.05783337727189064
# loss: 0.15022502839565277
# prediction/mean: 0.0677449107170105
# global_step: 51000
# test average loss% 0.1523

# %%
y_test_pred=reg.predict(
    input_fn=lambda:test_input_fn(dfn_test,batch_size))
py_test=[]
for i in range(len(dfn_test)):
    py_test.append(next(iter(y_test_pred))['predictions'][0])
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/boston-dnnregressor/model.ckpt-51000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
pl.figure(figsize=(12,4))
pl.plot(range(len(dfn_test)),dfn_test['MEDV'],
        '-o',label='real data',c='#55eeee',ms=7)
pl.plot(range(len(dfn_test)),py_test,
        '-o',label='predictions',c='#ee55ee',ms=5)
pl.tight_layout(); pl.grid(); pl.legend();
